# %% [markdown]
# # Cài đặt thư viện MinkowskiEngine để sử dụng Sparse Convolution

# %%
# Colab now uses a newer version of setuptools leading to errors with distutils.msvccompiler.
# Running this cell will cause a restart of the notebook, do that, but you can continue with the next cell after.

# !pip install setuptools==71.1.0
# Out:
# Collecting setuptools==71.1.0
#   Downloading setuptools-71.1.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-71.1.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.6 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-71.1.0

# %%
# Remove existing CUDA and NVIDIA setup

# !apt-get purge nvidia*
# !apt-get autoremove
# !apt-get autoclean
# !rm -rf /usr/local/cuda*
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'nvidia-driver-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.154.05' for glob 'nvidia*'
# Note, selecting 'nvidia-docker2' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-server-560.28.03' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-imex' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.154.05' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-390' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit-gcc' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-455' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-560.35.03' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-560.35.05' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-460' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-465' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-470' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-495' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-510' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-515' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-520' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-525' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-530' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-535' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-545' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-550' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-555' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-560' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-565' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-555-open' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-primus-vk-common' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-515' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-520' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-525' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-530' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-535' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-545' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-550' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-555' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-560' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open-565' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-texture-tools' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-525-open' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-utils' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-460' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-465' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-470' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-495' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-510' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-515' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-520' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-525' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-530' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-535' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-545' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-550' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-555' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-560' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-565' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-550-open' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-460' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-465' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-470' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-495' for glob 'nvidia*'
# Note, selecting 'nvidia-381-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-510' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-515' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-520' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-525' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-530' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-535' for glob 'nvidia*'
# Note, selecting 'nvidia-fs' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-545' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-550' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-555' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-560' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-565' for glob 'nvidia*'
# Note, selecting 'nvidia-container-runtime' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-390' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-410' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-430' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-435' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-455' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-460' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-465' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-470' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-495' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-565-server-565.57.01' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-550-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-510' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-515' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-520' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-525' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-530' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-535' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-545' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-550' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-555' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-560' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-565' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-545-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-560-open' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-387-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.90.07' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.90.12' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-520-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-primus-vk-wrapper' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-535-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-docker' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-560-open' for glob 'nvidia*'
# Note, selecting 'nvidia-378-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-313-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-560-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-open-560' for glob 'nvidia*'
# Note, selecting 'nvidia-open-565' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-565-565.77' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-545-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-430' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-435' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-455' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-460' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-465' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-470' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-495' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-510' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-515' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-520' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-525' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-530' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-535' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-545' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-550' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-555' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-560' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-565' for glob 'nvidia*'
# Note, selecting 'nvidia-319-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-530-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-565-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-egl-wayland-common' for glob 'nvidia*'
# Note, selecting 'nvidia-384-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-550-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-515-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-545-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-560-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-375-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-310-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-assistant' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.216.01' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.216.03' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-515-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.216.01' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.216.03' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-535-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-530-open' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-550-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-364-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-hpc-benchmarks-mpich' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.146.02' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-555-open' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-7' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-11-8' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-0' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-1' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-2' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-3' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-4' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-5' for glob 'nvidia*'
# Note, selecting 'nvidia-gds-12-6' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.146.02' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-545-server-545.29.06' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-565-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-565-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.67' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-560-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-555-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-525-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-515-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-530-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-390xx-opencl-icd' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.107.02' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-361-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.54.03' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.107.02' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-565-open' for glob 'nvidia*'
# Note, selecting 'nvidia-current-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-visual-profiler' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-367-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-396' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-545-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-418' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-455' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-460' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-465' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-470' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-495' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-535-open' for glob 'nvidia*'
# Note, selecting 'nvidia-legacy-390xx-smi' for glob 'nvidia*'
# Note, selecting 'nvidia-prebuilt-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-510' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-515' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-520' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-525' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-530' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-535' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-545' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-550' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-555' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-560' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-565' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-current' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.127.05' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.127.08' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-modules' for glob 'nvidia*'
# Note, selecting 'nvidia-egl-gbm1' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.127.05' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.127.08' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.161.07' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.161.08' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-server-560.35.03' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-server-560.35.05' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-358-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-515-open' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.161.07' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.161.08' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-565-open' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.171.04' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-gdb' for glob 'nvidia*'
# Note, selecting 'nvidia-340-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.171.04' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-545-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-560-560.28.03' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-535-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-550-open' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-prime' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-545-545.29.06' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.54.14' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.54.15' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-515-open' for glob 'nvidia*'
# Note, selecting 'nvidia-355-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-520-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-550-open' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-340' for glob 'nvidia*'
# Note, selecting 'nvidia-opencl-icd-384' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-open' for glob 'nvidia*'
# Note, selecting 'nvidia-304' for glob 'nvidia*'
# Note, selecting 'nvidia-310' for glob 'nvidia*'
# Note, selecting 'nvidia-313' for glob 'nvidia*'
# Note, selecting 'nvidia-319' for glob 'nvidia*'
# Note, selecting 'nvidia-325' for glob 'nvidia*'
# Note, selecting 'nvidia-331' for glob 'nvidia*'
# Note, selecting 'nvidia-334' for glob 'nvidia*'
# Note, selecting 'nvidia-337' for glob 'nvidia*'
# Note, selecting 'nvidia-340' for glob 'nvidia*'
# Note, selecting 'nvidia-343' for glob 'nvidia*'
# Note, selecting 'nvidia-346' for glob 'nvidia*'
# Note, selecting 'nvidia-349' for glob 'nvidia*'
# Note, selecting 'nvidia-352' for glob 'nvidia*'
# Note, selecting 'nvidia-355' for glob 'nvidia*'
# Note, selecting 'nvidia-358' for glob 'nvidia*'
# Note, selecting 'nvidia-361' for glob 'nvidia*'
# Note, selecting 'nvidia-364' for glob 'nvidia*'
# Note, selecting 'nvidia-367' for glob 'nvidia*'
# Note, selecting 'nvidia-375' for glob 'nvidia*'
# Note, selecting 'nvidia-378' for glob 'nvidia*'
# Note, selecting 'nvidia-381' for glob 'nvidia*'
# Note, selecting 'nvidia-384' for glob 'nvidia*'
# Note, selecting 'nvidia-387' for glob 'nvidia*'
# Note, selecting 'nvidia-390' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-dkms' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-565-server-565.77' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.120' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.135' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.142' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-535-open' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-prebuilt-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-550-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-530-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-520-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-535-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-settings' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-390' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-555-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-455' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-460' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-465' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-470' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-495' for glob 'nvidia*'
# Note, selecting 'nvidia-container-runtime-hook' for glob 'nvidia*'
# Note, selecting 'nvidia-cudnn' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-510' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-515' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-520' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-525' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-530' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-535' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-545' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-550' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-555' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-560' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-565' for glob 'nvidia*'
# Note, selecting 'nvidia-352-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-560-open' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-565-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-555-555.42.02' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-555-555.42.06' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-550-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.113.01' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-450' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-460' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-470' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-510' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-515' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-520' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-525' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-530' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-535' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-545' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-550' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-555' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-560' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-dev-565' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-565-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.113.01' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-530-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-343-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-520-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.54.14' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-server-550.54.15' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-510-server' for glob 'nvidia*'
# Note, selecting 'nvidia-349-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.67' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-450' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-460' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-555-server-555.42.02' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-555-server-555.42.06' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-470' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-510' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-515' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-520' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-525' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-530' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-535' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-545' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-550' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-555' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-560' for glob 'nvidia*'
# Note, selecting 'nvidia-fabricmanager-565' for glob 'nvidia*'
# Note, selecting 'nvidia-334-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-535-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-550-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-container-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-340' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-384' for glob 'nvidia*'
# Note, selecting 'nvidia-hpc-benchmarks-openmpi' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-555-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-550-open' for glob 'nvidia*'
# Note, selecting 'nvidia-hpc-benchmarks' for glob 'nvidia*'
# Note, selecting 'nvidia-container-toolkit-base' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.129.03' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-515-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-390' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-418' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-430' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-435' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-450' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-455' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-460' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-465' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-470' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-495' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-510' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-515' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-525-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-535-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-520' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-525' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-530' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-535' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-545' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-550' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-555' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-560' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-565' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-460-server' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-565-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-565-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-520-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.129.03' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-555-open' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.104.05' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.104.12' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-535-server-open' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-304' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-310' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-313' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-319' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-325' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-331' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-334' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-337' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-340' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-343' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-346' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-349' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-352' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-355' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-358' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-361' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-364' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-367' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-375' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-378' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-381' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-384' for glob 'nvidia*'
# Note, selecting 'nvidia-experimental-387' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.104.05' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.104.12' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-imex-550' for glob 'nvidia*'
# Note, selecting 'nvidia-imex-560' for glob 'nvidia*'
# Note, selecting 'nvidia-imex-565' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.86.05' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-535-open' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-525-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-560-server' for glob 'nvidia*'
# Note, selecting 'nvidia-337-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-gds' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.183.01' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-535.183.06' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.120' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.135' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.142' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.54.03' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-565-open' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-prebuilt' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-525-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-555-open' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.183.01' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-535-server-535.183.06' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-550-server' for glob 'nvidia*'
# Note, selecting 'nvidia-settings-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-kernel' for glob 'nvidia*'
# Note, selecting 'nvidia-modprobe' for glob 'nvidia*'
# Note, selecting 'nvidia-utils-470-server' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-565-server' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-535-open' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source' for glob 'nvidia*'
# Note, selecting 'nvidia-common' for glob 'nvidia*'
# Note, selecting 'nvidia-persistenced' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.90.07' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-550-550.90.12' for glob 'nvidia*'
# Note, selecting 'nvidia-firmware-565-565.57.01' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-no-dkms-525-open' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-smi' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-510-server' for glob 'nvidia*'
# Package 'nvidia-egl-wayland-common' is not installed, so not removed
# Note, selecting 'nvidia-settings' instead of 'nvidia-settings-binary'
# Package 'nvidia-390' is not installed, so not removed
# Note, selecting 'libnvtt-bin' instead of 'nvidia-texture-tools'
# Package 'nvidia-libopencl1-dev' is not installed, so not removed
# Package 'nvidia-current' is not installed, so not removed
# Package 'nvidia-current-updates' is not installed, so not removed
# Package 'nvidia-libopencl1' is not installed, so not removed
# Package 'nvidia' is not installed, so not removed
# Package 'nvidia-driver-410' is not installed, so not removed
# Package 'nvidia-387' is not installed, so not removed
# Package 'nvidia-387-updates' is not installed, so not removed
# Package 'nvidia-experimental-387' is not installed, so not removed
# Package 'nvidia-384-updates' is not installed, so not removed
# Package 'nvidia-experimental-384' is not installed, so not removed
# Package 'nvidia-381' is not installed, so not removed
# Package 'nvidia-381-updates' is not installed, so not removed
# Package 'nvidia-experimental-381' is not installed, so not removed
# Package 'nvidia-378' is not installed, so not removed
# Package 'nvidia-378-updates' is not installed, so not removed
# Package 'nvidia-experimental-378' is not installed, so not removed
# Package 'nvidia-375' is not installed, so not removed
# Package 'nvidia-375-updates' is not installed, so not removed
# Package 'nvidia-experimental-375' is not installed, so not removed
# Package 'nvidia-367' is not installed, so not removed
# Package 'nvidia-367-updates' is not installed, so not removed
# Package 'nvidia-experimental-367' is not installed, so not removed
# Package 'nvidia-364' is not installed, so not removed
# Package 'nvidia-364-updates' is not installed, so not removed
# Package 'nvidia-experimental-364' is not installed, so not removed
# Package 'nvidia-361' is not installed, so not removed
# Package 'nvidia-361-updates' is not installed, so not removed
# Package 'nvidia-experimental-361' is not installed, so not removed
# Package 'nvidia-358' is not installed, so not removed
# Package 'nvidia-358-updates' is not installed, so not removed
# Package 'nvidia-experimental-358' is not installed, so not removed
# Package 'nvidia-355' is not installed, so not removed
# Package 'nvidia-355-updates' is not installed, so not removed
# Package 'nvidia-experimental-355' is not installed, so not removed
# Package 'nvidia-352' is not installed, so not removed
# Package 'nvidia-352-updates' is not installed, so not removed
# Package 'nvidia-experimental-352' is not installed, so not removed
# Package 'nvidia-349' is not installed, so not removed
# Package 'nvidia-349-updates' is not installed, so not removed
# Package 'nvidia-experimental-349' is not installed, so not removed
# Package 'nvidia-346' is not installed, so not removed
# Package 'nvidia-346-updates' is not installed, so not removed
# Package 'nvidia-experimental-346' is not installed, so not removed
# Package 'nvidia-343' is not installed, so not removed
# Package 'nvidia-343-updates' is not installed, so not removed
# Package 'nvidia-experimental-343' is not installed, so not removed
# Package 'nvidia-340-updates' is not installed, so not removed
# Package 'nvidia-experimental-340' is not installed, so not removed
# Package 'nvidia-337' is not installed, so not removed
# Package 'nvidia-337-updates' is not installed, so not removed
# Package 'nvidia-experimental-337' is not installed, so not removed
# Package 'nvidia-334' is not installed, so not removed
# Package 'nvidia-334-updates' is not installed, so not removed
# Package 'nvidia-experimental-334' is not installed, so not removed
# Package 'nvidia-331' is not installed, so not removed
# Package 'nvidia-331-updates' is not installed, so not removed
# Package 'nvidia-experimental-331' is not installed, so not removed
# Package 'nvidia-325' is not installed, so not removed
# Package 'nvidia-325-updates' is not installed, so not removed
# Package 'nvidia-experimental-325' is not installed, so not removed
# Package 'nvidia-319' is not installed, so not removed
# Package 'nvidia-319-updates' is not installed, so not removed
# Package 'nvidia-experimental-319' is not installed, so not removed
# Package 'nvidia-313' is not installed, so not removed
# Package 'nvidia-313-updates' is not installed, so not removed
# Package 'nvidia-experimental-313' is not installed, so not removed
# Package 'nvidia-310' is not installed, so not removed
# Package 'nvidia-310-updates' is not installed, so not removed
# Package 'nvidia-experimental-310' is not installed, so not removed
# Package 'nvidia-304' is not installed, so not removed
# Package 'nvidia-304-updates' is not installed, so not removed
# Package 'nvidia-experimental-304' is not installed, so not removed
# Package 'nvidia-legacy-390xx-opencl-icd' is not installed, so not removed
# Package 'nvidia-legacy-390xx-smi' is not installed, so not removed
# Package 'nvidia-cuda-doc' is not installed, so not removed
# Package 'nvidia-firmware-535-server-535.113.01' is not installed, so not removed
# Package 'nvidia-firmware-535-server-535.146.02' is not installed, so not removed
# Package 'nvidia-firmware-535-server-535.171.04' is not installed, so not removed
# Package 'nvidia-firmware-535-535.104.12' is not installed, so not removed
# Package 'nvidia-firmware-535-535.161.08' is not installed, so not removed
# Package 'nvidia-firmware-535-535.183.06' is not installed, so not removed
# Package 'nvidia-firmware-535-535.216.01' is not installed, so not removed
# Package 'nvidia-firmware-535-535.216.03' is not installed, so not removed
# Package 'nvidia-firmware-545-server-545.29.06' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.107.02' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.120' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.67' is not installed, so not removed
# Package 'nvidia-driver-555-server' is not installed, so not removed
# Package 'nvidia-driver-555-server-open' is not installed, so not removed
# Package 'nvidia-container-runtime-hook' is not installed, so not removed
# Package 'nvidia-docker' is not installed, so not removed
# Package 'nvidia-firmware-555-server-555.42.02' is not installed, so not removed
# Package 'nvidia-firmware-555-server-555.42.06' is not installed, so not removed
# Package 'nvidia-fs-prebuilt' is not installed, so not removed
# Package 'nvidia-kernel-common-396' is not installed, so not removed
# Package 'nvidia-kernel-dkms' is not installed, so not removed
# Package 'nvidia-driver-560-server' is not installed, so not removed
# Package 'nvidia-driver-560-server-open' is not installed, so not removed
# Package 'nvidia-firmware-560-server-560.28.03' is not installed, so not removed
# Package 'nvidia-firmware-560-server-560.35.03' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.90.12' is not installed, so not removed
# Package 'nvidia-hpc-benchmarks' is not installed, so not removed
# Note, selecting 'libnvidia-gl-565' instead of 'nvidia-egl-gbm1'
# Package 'nvidia-firmware-560-server-560.35.05' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.135' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.142' is not installed, so not removed
# Package 'nvidia-firmware-565-server-565.77' is not installed, so not removed
# Package 'nvidia-prime' is not installed, so not removed
# Package 'nvidia-340' is not installed, so not removed
# Package 'nvidia-340-dev' is not installed, so not removed
# Package 'nvidia-340-uvm' is not installed, so not removed
# Package 'nvidia-compute-utils-418' is not installed, so not removed
# Package 'nvidia-compute-utils-435' is not installed, so not removed
# Package 'nvidia-compute-utils-440' is not installed, so not removed
# Package 'nvidia-compute-utils-450' is not installed, so not removed
# Package 'nvidia-compute-utils-455' is not installed, so not removed
# Package 'nvidia-dkms-418' is not installed, so not removed
# Package 'nvidia-dkms-435' is not installed, so not removed
# Package 'nvidia-dkms-440' is not installed, so not removed
# Package 'nvidia-dkms-450' is not installed, so not removed
# Package 'nvidia-dkms-455' is not installed, so not removed
# Package 'nvidia-driver-418' is not installed, so not removed
# Package 'nvidia-driver-435' is not installed, so not removed
# Package 'nvidia-driver-440' is not installed, so not removed
# Package 'nvidia-driver-450' is not installed, so not removed
# Package 'nvidia-driver-455' is not installed, so not removed
# Package 'nvidia-headless-418' is not installed, so not removed
# Package 'nvidia-headless-435' is not installed, so not removed
# Package 'nvidia-headless-440' is not installed, so not removed
# Package 'nvidia-headless-450' is not installed, so not removed
# Package 'nvidia-headless-455' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-418' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-435' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-440' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-450' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-455' is not installed, so not removed
# Package 'nvidia-kernel-common-418' is not installed, so not removed
# Package 'nvidia-kernel-common-435' is not installed, so not removed
# Package 'nvidia-kernel-common-440' is not installed, so not removed
# Package 'nvidia-kernel-common-450' is not installed, so not removed
# Package 'nvidia-kernel-common-455' is not installed, so not removed
# Package 'nvidia-kernel-source-418' is not installed, so not removed
# Package 'nvidia-kernel-source-435' is not installed, so not removed
# Package 'nvidia-kernel-source-440' is not installed, so not removed
# Package 'nvidia-kernel-source-450' is not installed, so not removed
# Package 'nvidia-kernel-source-455' is not installed, so not removed
# Package 'nvidia-utils-418' is not installed, so not removed
# Package 'nvidia-utils-435' is not installed, so not removed
# Package 'nvidia-utils-440' is not installed, so not removed
# Package 'nvidia-utils-450' is not installed, so not removed
# Package 'nvidia-utils-455' is not installed, so not removed
# Package 'nvidia-cg-dev' is not installed, so not removed
# Package 'nvidia-cg-doc' is not installed, so not removed
# Package 'nvidia-cg-toolkit' is not installed, so not removed
# Package 'nvidia-cuda-dev' is not installed, so not removed
# Package 'nvidia-cuda-gdb' is not installed, so not removed
# Package 'nvidia-cuda-toolkit' is not installed, so not removed
# Package 'nvidia-cuda-toolkit-doc' is not installed, so not removed
# Package 'nvidia-cuda-toolkit-gcc' is not installed, so not removed
# Package 'nvidia-cudnn' is not installed, so not removed
# Package 'nvidia-libopencl1-340' is not installed, so not removed
# Package 'nvidia-opencl-icd-340' is not installed, so not removed
# Package 'nvidia-primus-vk-common' is not installed, so not removed
# Package 'nvidia-primus-vk-wrapper' is not installed, so not removed
# Package 'nvidia-profiler' is not installed, so not removed
# Package 'nvidia-visual-profiler' is not installed, so not removed
# Package 'nvidia-384' is not installed, so not removed
# Package 'nvidia-384-dev' is not installed, so not removed
# Package 'nvidia-compute-utils-390' is not installed, so not removed
# Package 'nvidia-compute-utils-418-server' is not installed, so not removed
# Package 'nvidia-compute-utils-440-server' is not installed, so not removed
# Package 'nvidia-compute-utils-450-server' is not installed, so not removed
# ...
# Package 'nvidia-kernel-common-520' is not installed, so not removed
# Package 'nvidia-kernel-common-525' is not installed, so not removed
# Package 'nvidia-kernel-common-525-server' is not installed, so not removed
# Package 'nvidia-kernel-common-535-server' is not installed, so not removed
# Package 'nvidia-kernel-common-545' is not installed, so not removed
# Package 'nvidia-kernel-common-550-server' is not installed, so not removed
# Package 'nvidia-kernel-common-565-server' is not installed, so not removed
# Package 'nvidia-kernel-source-390' is not installed, so not removed
# Package 'nvidia-kernel-source-418-server' is not installed, so not removed
# Package 'nvidia-kernel-source-440-server' is not installed, so not removed
# Package 'nvidia-kernel-source-450-server' is not installed, so not removed
# Package 'nvidia-kernel-source-460' is not installed, so not removed
# Package 'nvidia-kernel-source-460-server' is not installed, so not removed
# Package 'nvidia-kernel-source-465' is not installed, so not removed
# Package 'nvidia-kernel-source-470' is not installed, so not removed
# Package 'nvidia-kernel-source-470-server' is not installed, so not removed
# Package 'nvidia-kernel-source-495' is not installed, so not removed
# Package 'nvidia-kernel-source-510' is not installed, so not removed
# Package 'nvidia-kernel-source-510-server' is not installed, so not removed
# Package 'nvidia-kernel-source-515' is not installed, so not removed
# Package 'nvidia-kernel-source-515-open' is not installed, so not removed
# Package 'nvidia-kernel-source-515-server' is not installed, so not removed
# Package 'nvidia-kernel-source-520' is not installed, so not removed
# Package 'nvidia-kernel-source-520-open' is not installed, so not removed
# Package 'nvidia-kernel-source-525' is not installed, so not removed
# Package 'nvidia-kernel-source-525-open' is not installed, so not removed
# Package 'nvidia-kernel-source-525-server' is not installed, so not removed
# Package 'nvidia-kernel-source-535-open' is not installed, so not removed
# Package 'nvidia-kernel-source-535-server' is not installed, so not removed
# Package 'nvidia-kernel-source-535-server-open' is not installed, so not removed
# Package 'nvidia-kernel-source-545' is not installed, so not removed
# Package 'nvidia-kernel-source-545-open' is not installed, so not removed
# Package 'nvidia-kernel-source-550-server' is not installed, so not removed
# Package 'nvidia-kernel-source-550-server-open' is not installed, so not removed
# Package 'nvidia-kernel-source-565-server' is not installed, so not removed
# Package 'nvidia-kernel-source-565-server-open' is not installed, so not removed
# Package 'nvidia-utils-390' is not installed, so not removed
# Package 'nvidia-utils-418-server' is not installed, so not removed
# Package 'nvidia-utils-440-server' is not installed, so not removed
# Package 'nvidia-utils-450-server' is not installed, so not removed
# Package 'nvidia-utils-460' is not installed, so not removed
# Package 'nvidia-utils-460-server' is not installed, so not removed
# Package 'nvidia-utils-465' is not installed, so not removed
# Package 'nvidia-utils-470' is not installed, so not removed
# Package 'nvidia-utils-470-server' is not installed, so not removed
# Package 'nvidia-utils-495' is not installed, so not removed
# Package 'nvidia-utils-510' is not installed, so not removed
# Package 'nvidia-utils-510-server' is not installed, so not removed
# Package 'nvidia-utils-515' is not installed, so not removed
# Package 'nvidia-utils-515-server' is not installed, so not removed
# Package 'nvidia-utils-520' is not installed, so not removed
# Package 'nvidia-utils-525' is not installed, so not removed
# Package 'nvidia-utils-525-server' is not installed, so not removed
# Package 'nvidia-utils-535-server' is not installed, so not removed
# Package 'nvidia-utils-545' is not installed, so not removed
# Package 'nvidia-utils-550-server' is not installed, so not removed
# Package 'nvidia-utils-565-server' is not installed, so not removed
# Package 'nvidia-common' is not installed, so not removed
# Package 'nvidia-fabricmanager-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-460' is not installed, so not removed
# Package 'nvidia-fabricmanager-470' is not installed, so not removed
# Package 'nvidia-fabricmanager-510' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-450' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-460' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-470' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-510' is not installed, so not removed
# Package 'nvidia-firmware-550-server-550.54.14' is not installed, so not removed
# Package 'nvidia-libopencl1-384' is not installed, so not removed
# Package 'nvidia-opencl-icd-384' is not installed, so not removed
# Package 'nvidia-compute-utils-430' is not installed, so not removed
# Package 'nvidia-compute-utils-555' is not installed, so not removed
# Package 'nvidia-container-runtime' is not installed, so not removed
# Package 'nvidia-dkms-430' is not installed, so not removed
# Package 'nvidia-dkms-555' is not installed, so not removed
# Package 'nvidia-dkms-555-open' is not installed, so not removed
# Package 'nvidia-docker2' is not installed, so not removed
# Package 'nvidia-driver-430' is not installed, so not removed
# Package 'nvidia-driver-555' is not installed, so not removed
# Package 'nvidia-driver-555-open' is not installed, so not removed
# Package 'nvidia-fabricmanager-520' is not installed, so not removed
# Package 'nvidia-fabricmanager-525' is not installed, so not removed
# Package 'nvidia-fabricmanager-530' is not installed, so not removed
# Package 'nvidia-fabricmanager-545' is not installed, so not removed
# Package 'nvidia-fabricmanager-555' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-520' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-525' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-530' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-545' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-555' is not installed, so not removed
# Package 'nvidia-firmware-550-550.54.14' is not installed, so not removed
# Package 'nvidia-firmware-550-550.54.15' is not installed, so not removed
# Package 'nvidia-firmware-550-550.90.07' is not installed, so not removed
# Package 'nvidia-firmware-555-555.42.02' is not installed, so not removed
# Package 'nvidia-firmware-555-555.42.06' is not installed, so not removed
# Package 'nvidia-gds-11-7' is not installed, so not removed
# Package 'nvidia-gds-11-8' is not installed, so not removed
# Package 'nvidia-gds-12-0' is not installed, so not removed
# Package 'nvidia-gds-12-1' is not installed, so not removed
# Package 'nvidia-gds-12-2' is not installed, so not removed
# Package 'nvidia-gds-12-3' is not installed, so not removed
# Package 'nvidia-gds-12-4' is not installed, so not removed
# Package 'nvidia-gds-12-5' is not installed, so not removed
# Package 'nvidia-headless-430' is not installed, so not removed
# Package 'nvidia-headless-555' is not installed, so not removed
# Package 'nvidia-headless-555-open' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-430' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-555' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-555-open' is not installed, so not removed
# Package 'nvidia-kernel-common-430' is not installed, so not removed
# Package 'nvidia-kernel-common-555' is not installed, so not removed
# Package 'nvidia-kernel-open-515' is not installed, so not removed
# Package 'nvidia-kernel-open-520' is not installed, so not removed
# Package 'nvidia-kernel-open-525' is not installed, so not removed
# Package 'nvidia-kernel-open-530' is not installed, so not removed
# Package 'nvidia-kernel-open-545' is not installed, so not removed
# Package 'nvidia-kernel-open-555' is not installed, so not removed
# Package 'nvidia-kernel-source-430' is not installed, so not removed
# Package 'nvidia-kernel-source-555' is not installed, so not removed
# Package 'nvidia-kernel-source-555-open' is not installed, so not removed
# Package 'nvidia-utils-430' is not installed, so not removed
# Package 'nvidia-utils-555' is not installed, so not removed
# Package 'nvidia-firmware-560-560.28.03' is not installed, so not removed
# Package 'nvidia-fs' is not installed, so not removed
# Package 'nvidia-fs-dkms' is not installed, so not removed
# Package 'nvidia-imex' is not installed, so not removed
# Package 'nvidia-compute-utils-530' is not installed, so not removed
# Package 'nvidia-dkms-530' is not installed, so not removed
# Package 'nvidia-dkms-530-open' is not installed, so not removed
# Package 'nvidia-driver-530' is not installed, so not removed
# Package 'nvidia-driver-530-open' is not installed, so not removed
# Package 'nvidia-firmware-560-560.35.03' is not installed, so not removed
# Package 'nvidia-headless-530' is not installed, so not removed
# Package 'nvidia-headless-530-open' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-530' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-530-open' is not installed, so not removed
# Package 'nvidia-kernel-common-530' is not installed, so not removed
# Package 'nvidia-kernel-source-530' is not installed, so not removed
# Package 'nvidia-kernel-source-530-open' is not installed, so not removed
# Package 'nvidia-utils-530' is not installed, so not removed
# Package 'nvidia-firmware-550-550.90.12' is not installed, so not removed
# Package 'nvidia-hpc-benchmarks-mpich' is not installed, so not removed
# Package 'nvidia-hpc-benchmarks-openmpi' is not installed, so not removed
# Package 'nvidia-firmware-550-550.127.05' is not installed, so not removed
# Package 'nvidia-driver-assistant' is not installed, so not removed
# Package 'nvidia-fabricmanager-565' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-565' is not installed, so not removed
# Package 'nvidia-firmware-565-565.57.01' is not installed, so not removed
# Package 'nvidia-imex-565' is not installed, so not removed
# Package 'nvidia-kernel-open-565' is not installed, so not removed
# Package 'nvidia-modprobe' is not installed, so not removed
# Package 'nvidia-open-565' is not installed, so not removed
# Package 'nvidia-open' is not installed, so not removed
# Package 'nvidia-settings' is not installed, so not removed
# Package 'nvidia-compute-utils-535' is not installed, so not removed
# Package 'nvidia-dkms-535' is not installed, so not removed
# Package 'nvidia-driver-535' is not installed, so not removed
# Package 'nvidia-fabricmanager-535' is not installed, so not removed
# Package 'nvidia-fabricmanager-550' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-535' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-550' is not installed, so not removed
# Package 'nvidia-firmware-550-550.127.08' is not installed, so not removed
# Package 'nvidia-headless-535' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-535' is not installed, so not removed
# Package 'nvidia-imex-550' is not installed, so not removed
# Package 'nvidia-kernel-common-535' is not installed, so not removed
# Package 'nvidia-kernel-open-535' is not installed, so not removed
# Package 'nvidia-kernel-open-550' is not installed, so not removed
# Package 'nvidia-kernel-source-535' is not installed, so not removed
# Package 'nvidia-utils-535' is not installed, so not removed
# Package 'nvidia-compute-utils-560' is not installed, so not removed
# Package 'nvidia-dkms-560' is not installed, so not removed
# Package 'nvidia-dkms-560-open' is not installed, so not removed
# Package 'nvidia-driver-560' is not installed, so not removed
# Package 'nvidia-driver-560-open' is not installed, so not removed
# Package 'nvidia-fabricmanager-560' is not installed, so not removed
# Package 'nvidia-fabricmanager-dev-560' is not installed, so not removed
# Package 'nvidia-firmware-560-560.35.05' is not installed, so not removed
# Package 'nvidia-gds-12-6' is not installed, so not removed
# Package 'nvidia-gds' is not installed, so not removed
# Package 'nvidia-headless-560' is not installed, so not removed
# Package 'nvidia-headless-560-open' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-560' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-560-open' is not installed, so not removed
# Package 'nvidia-imex-560' is not installed, so not removed
# Package 'nvidia-kernel-common-560' is not installed, so not removed
# Package 'nvidia-kernel-open-560' is not installed, so not removed
# Package 'nvidia-kernel-source-560' is not installed, so not removed
# Package 'nvidia-kernel-source-560-open' is not installed, so not removed
# Package 'nvidia-open-560' is not installed, so not removed
# Package 'nvidia-utils-560' is not installed, so not removed
# Package 'nvidia-container-toolkit' is not installed, so not removed
# Package 'nvidia-container-toolkit-base' is not installed, so not removed
# Package 'nvidia-compute-utils-550' is not installed, so not removed
# Package 'nvidia-compute-utils-565' is not installed, so not removed
# Package 'nvidia-dkms-550' is not installed, so not removed
# Package 'nvidia-dkms-550-open' is not installed, so not removed
# Package 'nvidia-dkms-565' is not installed, so not removed
# Package 'nvidia-dkms-565-open' is not installed, so not removed
# Package 'nvidia-driver-550' is not installed, so not removed
# Package 'nvidia-driver-550-open' is not installed, so not removed
# Package 'nvidia-driver-565' is not installed, so not removed
# Package 'nvidia-driver-565-open' is not installed, so not removed
# Package 'nvidia-firmware-550-550.135' is not installed, so not removed
# Package 'nvidia-firmware-550-550.142' is not installed, so not removed
# Package 'nvidia-firmware-565-565.77' is not installed, so not removed
# Package 'nvidia-headless-550' is not installed, so not removed
# Package 'nvidia-headless-550-open' is not installed, so not removed
# Package 'nvidia-headless-565' is not installed, so not removed
# Package 'nvidia-headless-565-open' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-550' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-550-open' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-565' is not installed, so not removed
# Package 'nvidia-headless-no-dkms-565-open' is not installed, so not removed
# Package 'nvidia-kernel-common-550' is not installed, so not removed
# Package 'nvidia-kernel-common-565' is not installed, so not removed
# Package 'nvidia-kernel-source-550' is not installed, so not removed
# Package 'nvidia-kernel-source-550-open' is not installed, so not removed
# Package 'nvidia-kernel-source-565' is not installed, so not removed
# Package 'nvidia-kernel-source-565-open' is not installed, so not removed
# Package 'nvidia-utils-550' is not installed, so not removed
# Package 'nvidia-utils-565' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   ocl-icd-opencl-dev opencl-c-headers opencl-clhpp-headers
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   nvidia-opencl-dev*
# 0 upgraded, 0 newly installed, 1 to remove and 49 not upgraded.
# After this operation, 88.1 kB disk space will be freed.
# (Reading database ... 123634 files and directories currently installed.)
# Removing nvidia-opencl-dev:amd64 (11.5.1-1ubuntu1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be REMOVED:
#   ocl-icd-opencl-dev opencl-c-headers opencl-clhpp-headers
# 0 upgraded, 0 newly installed, 3 to remove and 49 not upgraded.
# After this operation, 736 kB disk space will be freed.
# (Reading database ... 123631 files and directories currently installed.)
# Removing ocl-icd-opencl-dev:amd64 (2.2.14-3) ...
# Removing opencl-clhpp-headers (3.0~2.0.15-1ubuntu1) ...
# Removing opencl-c-headers (3.0~2022.01.04-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done

# %%
# Install CUDA 10-2

# The below set of commands were copied from Nvidia's installation instructions with some slight modifications:
# https://developer.nvidia.com/cuda-10.2-download-archive?target_os=Linux&target_arch=x86_64&target_distro=Ubuntu&target_version=1804&target_type=deblocal

# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# !apt-key add /var/cuda-repo-10-2-local-10.2.89-440.33.01/7fa2af80.pub
# !apt-get update
# !DEBIAN_FRONTEND=noninteractive apt-get -y install cuda-10-2
# !update-alternatives --install /usr/local/cuda cuda /usr/local/cuda-10.2 1
# Out:
# --2025-01-03 07:48:18--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 23.60.173.16, 23.60.173.59
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|23.60.173.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [text/plain]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2025-01-03 07:48:18 (91.0 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]
#
# --2025-01-03 07:48:18--  https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 23.60.173.16, 23.60.173.59
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|23.60.173.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1896270068 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb’
#
# cuda-repo-ubuntu180 100%[===================>]   1.77G   136MB/s    in 20s
#
# 2025-01-03 07:48:39 (88.9 MB/s) - ‘cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb’ saved [1896270068/1896270068]
#
# Selecting previously unselected package cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01.
# (Reading database ... 123595 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01 (1.0-1) ...
# Setting up cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01 (1.0-1) ...
#
# The public CUDA GPG key does not appear to be installed.
# To install the key, run this command:
# sudo apt-key add /var/cuda-repo-10-2-local-10.2.89-440.33.01/7fa2af80.pub
#
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Get:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Ign:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Get:3 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release.gpg [833 B]
# Get:3 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release.gpg [833 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Packages [23.8 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,197 kB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,632 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,448 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,840 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,563 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,517 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,633 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,517 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [81.4 kB]
# Fetched 28.1 MB in 4s (7,639 kB/s)
# Reading package lists... Done
# W: file:/var/cuda-repo-10-2-local-10.2.89-440.33.01/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2 cuda-cudart-dev-10-2
#   cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2 cuda-cupti-10-2 cuda-cupti-dev-10-2
#   cuda-curand-10-2 cuda-curand-dev-10-2 cuda-cusolver-10-2 cuda-cusolver-dev-10-2
#   cuda-cusparse-10-2 cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-drivers cuda-drivers-565 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2 cuda-misc-headers-10-2 cuda-npp-10-2
#   cuda-npp-dev-10-2 cuda-nsight-10-2 cuda-nsight-compute-10-2 cuda-nsight-systems-10-2
#   cuda-nvcc-10-2 cuda-nvdisasm-10-2 cuda-nvgraph-10-2 cuda-nvgraph-dev-10-2 cuda-nvjpeg-10-2
#   cuda-nvjpeg-dev-10-2 cuda-nvml-dev-10-2 cuda-nvprof-10-2 cuda-nvprune-10-2 cuda-nvrtc-10-2
#   cuda-nvrtc-dev-10-2 cuda-nvtx-10-2 cuda-nvvp-10-2 cuda-runtime-10-2 cuda-samples-10-2
#   cuda-sanitizer-api-10-2 cuda-toolkit-10-2 cuda-tools-10-2 cuda-visual-tools-10-2 dctrl-tools
#   default-jre default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra freeglut3
#   freeglut3-dev gcc-12 keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni
#   libcublas-dev libcublas10 libegl-dev libfakeroot libfontenc1 libgail-common libgail18
#   libgcc-12-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libice-dev
#   libjansson4 liblocale-gettext-perl libnvidia-cfg1-565 libnvidia-common-565 libnvidia-compute-565
#   libnvidia-decode-565 libnvidia-encode-565 libnvidia-extra-565 libnvidia-fbc1-565 libnvidia-gl-565
#   libopengl-dev librsvg2-common libsm-dev libtsan2 libudev1 libxcb-cursor0 libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0
#   libxcb-xkb1 libxcvt0 libxfixes-dev libxfont2 libxi-dev libxkbcommon-x11-0 libxkbfile1 libxmu-dev
#   libxmu-headers libxt-dev libxtst6 libxxf86dga1 nsight-systems-2024.5.1 nvidia-compute-utils-565
#   nvidia-dkms-565 nvidia-driver-565 nvidia-firmware-565-565.57.01 nvidia-kernel-common-565
#   nvidia-kernel-source-565 nvidia-modprobe nvidia-prime nvidia-settings nvidia-utils-565
#   openjdk-11-jre python3-xkit screen-resolution-extra systemd-hwe-hwdb udev x11-utils x11-xkb-utils
#   xcvt xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-565
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc gvfs libice-doc libsm-doc
#   libxt-doc mesa-utils xfs | xserver xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-565:i386 libnvidia-decode-565:i386 libnvidia-encode-565:i386
#   libnvidia-fbc1-565:i386 libnvidia-gl-565:i386
# The following NEW packages will be installed:
#   cpp-12 cuda-10-2 cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2 cuda-cupti-10-2
#   cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2 cuda-cusolver-10-2
#   cuda-cusolver-dev-10-2 cuda-cusparse-10-2 cuda-cusparse-dev-10-2 cuda-demo-suite-10-2
#   cuda-documentation-10-2 cuda-driver-dev-10-2 cuda-drivers cuda-drivers-565 cuda-gdb-10-2
#   cuda-libraries-10-2 cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2 cuda-nsight-compute-10-2
#   cuda-nsight-systems-10-2 cuda-nvcc-10-2 cuda-nvdisasm-10-2 cuda-nvgraph-10-2
#   cuda-nvgraph-dev-10-2 cuda-nvjpeg-10-2 cuda-nvjpeg-dev-10-2 cuda-nvml-dev-10-2 cuda-nvprof-10-2
#   cuda-nvprune-10-2 cuda-nvrtc-10-2 cuda-nvrtc-dev-10-2 cuda-nvtx-10-2 cuda-nvvp-10-2
#   cuda-runtime-10-2 cuda-samples-10-2 cuda-sanitizer-api-10-2 cuda-toolkit-10-2 cuda-tools-10-2
#   cuda-visual-tools-10-2 dctrl-tools default-jre default-jre-headless dkms fakeroot
#   fonts-dejavu-core fonts-dejavu-extra freeglut3 freeglut3-dev gcc-12 keyboard-configuration
#   libasan8 libatk-wrapper-java libatk-wrapper-java-jni libcublas-dev libcublas10 libegl-dev
#   libfakeroot libfontenc1 libgail-common libgail18 libgcc-12-dev libgl-dev libgl1-mesa-dev
#   libgles-dev libgles1 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libice-dev libjansson4 liblocale-gettext-perl
#   libnvidia-cfg1-565 libnvidia-common-565 libnvidia-compute-565 libnvidia-decode-565
#   libnvidia-encode-565 libnvidia-extra-565 libnvidia-fbc1-565 libnvidia-gl-565 libopengl-dev
#   librsvg2-common libsm-dev libtsan2 libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcvt0
#   libxfixes-dev libxfont2 libxi-dev libxkbcommon-x11-0 libxkbfile1 libxmu-dev libxmu-headers
#   libxt-dev libxtst6 libxxf86dga1 nsight-systems-2024.5.1 nvidia-compute-utils-565 nvidia-dkms-565
#   nvidia-driver-565 nvidia-firmware-565-565.57.01 nvidia-kernel-common-565 nvidia-kernel-source-565
#   nvidia-modprobe nvidia-prime nvidia-settings nvidia-utils-565 openjdk-11-jre python3-xkit
#   screen-resolution-extra systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt xfonts-base
#   xfonts-encodings xfonts-utils xserver-common xserver-xorg-core xserver-xorg-video-nvidia-565
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 146 newly installed, 0 to remove and 54 not upgraded.
# Need to get 717 MB/2,145 MB of archives.
# After this operation, 4,526 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-license-10-2 10.2.89-1 [16.4 kB]
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-misc-headers-10-2 10.2.89-1 [1,111 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.5.1 2024.5.1.113-245134619542v0 [356 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:6 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvcc-10-2 10.2.89-1 [37.4 MB]
# Get:7 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cuobjdump-10-2 10.2.89-1 [88.5 kB]
# Get:8 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvprune-10-2 10.2.89-1 [39.5 kB]
# Get:9 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-compiler-10-2 10.2.89-1 [2,530 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:11 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvdisasm-10-2 10.2.89-1 [22.2 MB]
# Get:12 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-gdb-10-2 10.2.89-1 [2,769 kB]
# Get:13 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvprof-10-2 10.2.89-1 [1,651 kB]
# Get:14 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-sanitizer-api-10-2 10.2.89-1 [2,161 kB]
# Get:15 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-memcheck-10-2 10.2.89-1 [139 kB]
# Get:16 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cudart-10-2 10.2.89-1 [111 kB]
# Get:17 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-driver-dev-10-2 10.2.89-1 [11.8 kB]
# Get:18 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cudart-dev-10-2 10.2.89-1 [491 kB]
# Get:19 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cupti-10-2 10.2.89-1 [8,169 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:21 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cupti-dev-10-2 10.2.89-1 [2,197 kB]
# Get:22 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvtx-10-2 10.2.89-1 [38.9 kB]
# Get:23 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-command-line-tools-10-2 10.2.89-1 [27.0 kB]
# Get:24 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-10-2 10.2.89-1 [2,582 B]
# Get:25 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvvp-10-2 10.2.89-1 [2,532 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:29 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvrtc-10-2 10.2.89-1 [6,413 kB]
# Get:30 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvrtc-dev-10-2 10.2.89-1 [8,822 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:59 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3-dev amd64 2.8.1-6 [126 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-headers all 2:1.1.3-3 [54.1 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-dev amd64 2:1.1.3-3 [54.6 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.12 [1,477 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/main amd64 nvidia-prime all 0.8.17.1 [9,956 B]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:99 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusolver-10-2 10.2.89-1 [85.6 MB]
# Get:100 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusolver-dev-10-2 10.2.89-1 [15.2 MB]
# Get:101 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  libcublas10 10.2.2.89-1 [42.2 MB]
# Get:102 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  libcublas-dev 10.2.2.89-1 [42.3 MB]
# Get:103 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cufft-10-2 10.2.89-1 [87.8 MB]
# Get:104 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-565 565.57.01-0ubuntu1 [15.7 kB]
# Get:105 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cufft-dev-10-2 10.2.89-1 [164 MB]
# Get:106 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-565 565.57.01-0ubuntu1 [2,105 kB]
# Get:107 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-565 565.57.01-0ubuntu1 [55.6 MB]
# Get:108 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-curand-10-2 10.2.89-1 [38.9 MB]
# Get:109 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-curand-dev-10-2 10.2.89-1 [39.1 MB]
# Get:110 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-565 565.57.01-0ubuntu1 [139 MB]
# Get:111 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusparse-10-2 10.2.89-1 [59.2 MB]
# Get:112 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusparse-dev-10-2 10.2.89-1 [59.7 MB]
# Get:113 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-npp-10-2 10.2.89-1 [56.7 MB]
# Get:114 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-npp-dev-10-2 10.2.89-1 [57.6 MB]
# Get:115 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvml-dev-10-2 10.2.89-1 [53.8 kB]
# Get:116 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvjpeg-10-2 10.2.89-1 [1,274 kB]
# Get:117 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvjpeg-dev-10-2 10.2.89-1 [1,213 kB]
# Get:118 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-compute-10-2 10.2.89-1 [3,712 B]
# Get:119 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-systems-10-2 10.2.89-1 [3,130 B]
# Get:120 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvgraph-10-2 10.2.89-1 [44.5 MB]
# Get:121 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvgraph-dev-10-2 10.2.89-1 [35.2 MB]
# Get:122 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-565 565.57.01-0ubuntu1 [54.1 MB]
# Get:123 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-565-565.57.01 565.57.01-0ubuntu1 [48.4 MB]
# Get:124 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-visual-tools-10-2 10.2.89-1 [389 MB]
# Get:125 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-tools-10-2 10.2.89-1 [2,496 B]
# Get:126 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-samples-10-2 10.2.89-1 [65.6 MB]
# Get:127 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-documentation-10-2 10.2.89-1 [54.1 MB]
# Get:128 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-libraries-dev-10-2 10.2.89-1 [2,614 B]
# Get:129 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-libraries-10-2 10.2.89-1 [2,584 B]
# Get:130 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-toolkit-10-2 10.2.89-1 [2,830 B]
# Get:131 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-runtime-10-2 10.2.89-1 [2,532 B]
# Get:132 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-demo-suite-10-2 10.2.89-1 [3,880 kB]
# Get:133 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-10-2 10.2.89-1 [2,558 B]
# Get:134 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-modprobe 565.57.01-0ubuntu1 [21.7 kB]
# Get:135 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-565 565.57.01-0ubuntu1 [97.6 kB]
# Get:136 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-565 565.57.01-0ubuntu1 [34.4 kB]
# Get:137 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-565 565.57.01-0ubuntu1 [71.5 kB]
# Get:138 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-565 565.57.01-0ubuntu1 [107 kB]
# Get:139 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-565 565.57.01-0ubuntu1 [105 kB]
# Get:140 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-565 565.57.01-0ubuntu1 [498 kB]
# Get:141 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-565 565.57.01-0ubuntu1 [145 kB]
# Get:142 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-565 565.57.01-0ubuntu1 [1,614 kB]
# Get:143 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-565 565.57.01-0ubuntu1 [92.9 kB]
# Get:144 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-565 565.57.01-0ubuntu1 [488 kB]
# Get:145 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers-565 565.57.01-0ubuntu1 [2,546 B]
# Get:146 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers 565.57.01-0ubuntu1 [2,494 B]
# Get:147 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 565.57.01-0ubuntu1 [959 kB]
# Fetched 717 MB in 20s (35.7 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 123683 files and directories currently installed.)
# Preparing to unpack .../0-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../1-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../2-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../3-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../4-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../5-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../6-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../7-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../8-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Preparing to unpack .../9-libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 124043 files and directories currently installed.)
# Preparing to unpack .../000-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../001-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package cuda-license-10-2.
# Preparing to unpack .../002-cuda-license-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-license-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-misc-headers-10-2.
# Preparing to unpack .../003-cuda-misc-headers-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-misc-headers-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvcc-10-2.
# Preparing to unpack .../004-cuda-nvcc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvcc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-2.
# Preparing to unpack .../005-cuda-cuobjdump-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprune-10-2.
# Preparing to unpack .../006-cuda-nvprune-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprune-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-compiler-10-2.
# Preparing to unpack .../007-cuda-compiler-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-compiler-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-2.
# Preparing to unpack .../008-cuda-nvdisasm-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-gdb-10-2.
# Preparing to unpack .../009-cuda-gdb-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-gdb-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprof-10-2.
# Preparing to unpack .../010-cuda-nvprof-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprof-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-sanitizer-api-10-2.
# Preparing to unpack .../011-cuda-sanitizer-api-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-memcheck-10-2.
# Preparing to unpack .../012-cuda-memcheck-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-memcheck-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-10-2.
# Preparing to unpack .../013-cuda-cudart-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-driver-dev-10-2.
# Preparing to unpack .../014-cuda-driver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-10-2.
# Preparing to unpack .../015-cuda-cudart-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-10-2.
# Preparing to unpack .../016-cuda-cupti-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-dev-10-2.
# Preparing to unpack .../017-cuda-cupti-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvtx-10-2.
# Preparing to unpack .../018-cuda-nvtx-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvtx-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-2.
# Preparing to unpack .../019-cuda-command-line-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../020-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../021-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../022-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../023-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-10-2.
# Preparing to unpack .../024-cuda-nsight-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvvp-10-2.
# Preparing to unpack .../025-cuda-nvvp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvvp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-10-2.
# Preparing to unpack .../026-cuda-nvrtc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-10-2.
# Preparing to unpack .../027-cuda-nvrtc-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-10-2.
# Preparing to unpack .../028-cuda-cusolver-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-dev-10-2.
# Preparing to unpack .../029-cuda-cusolver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package libcublas10.
# Preparing to unpack .../030-libcublas10_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas10 (10.2.2.89-1) ...
# Selecting previously unselected package libcublas-dev.
# Preparing to unpack .../031-libcublas-dev_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.2.89-1) ...
# Selecting previously unselected package cuda-cufft-10-2.
# Preparing to unpack .../032-cuda-cufft-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cufft-dev-10-2.
# Preparing to unpack .../033-cuda-cufft-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-10-2.
# Preparing to unpack .../034-cuda-curand-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-dev-10-2.
# Preparing to unpack .../035-cuda-curand-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-10-2.
# Preparing to unpack .../036-cuda-cusparse-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-dev-10-2.
# Preparing to unpack .../037-cuda-cusparse-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-10-2.
# Preparing to unpack .../038-cuda-npp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-dev-10-2.
# Preparing to unpack .../039-cuda-npp-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-2.
# Preparing to unpack .../040-cuda-nvml-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-10-2.
# Preparing to unpack .../041-cuda-nvjpeg-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-dev-10-2.
# Preparing to unpack .../042-cuda-nvjpeg-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-2.
# Preparing to unpack .../043-cuda-nsight-compute-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-2 (10.2.89-1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../044-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../045-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../046-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../047-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../048-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../049-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../050-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../051-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../052-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../053-libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Selecting previously unselected package nsight-systems-2024.5.1.
# Preparing to unpack .../054-nsight-systems-2024.5.1_2024.5.1.113-245134619542v0_amd64.deb ...
# Unpacking nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# Selecting previously unselected package cuda-nsight-systems-10-2.
# Preparing to unpack .../055-cuda-nsight-systems-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-systems-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-10-2.
# Preparing to unpack .../056-cuda-nvgraph-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-10-2.
# Preparing to unpack .../057-cuda-nvgraph-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-visual-tools-10-2.
# Preparing to unpack .../058-cuda-visual-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-tools-10-2.
# Preparing to unpack .../059-cuda-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../060-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../061-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../062-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../063-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../064-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../065-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../066-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../067-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../068-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../069-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../070-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../071-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../072-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../073-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../074-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../075-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../076-libxmu-headers_2%3a1.1.3-3_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-3) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../077-libxmu-dev_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../078-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../079-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package cuda-samples-10-2.
# Preparing to unpack .../080-cuda-samples-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-samples-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-documentation-10-2.
# Preparing to unpack .../081-cuda-documentation-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-documentation-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-dev-10-2.
# Preparing to unpack .../082-cuda-libraries-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-10-2.
# Preparing to unpack .../083-cuda-libraries-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-toolkit-10-2.
# Preparing to unpack .../084-cuda-toolkit-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-toolkit-10-2 (10.2.89-1) ...
# Selecting previously unselected package libnvidia-common-565.
# Preparing to unpack .../085-libnvidia-common-565_565.57.01-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-565:amd64.
# Preparing to unpack .../086-libnvidia-decode-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-565:amd64.
# Preparing to unpack .../087-libnvidia-compute-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-565:amd64.
# Preparing to unpack .../088-libnvidia-gl-565_565.57.01-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-565.
# Preparing to unpack .../089-nvidia-kernel-source-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-565-565.57.01.
# Preparing to unpack .../090-nvidia-firmware-565-565.57.01_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-565-565.57.01 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../091-nvidia-modprobe_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-565.
# Preparing to unpack .../092-nvidia-kernel-common-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-565.
# Preparing to unpack .../093-nvidia-dkms-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-565:amd64.
# Preparing to unpack .../094-libnvidia-extra-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-565.
# Preparing to unpack .../095-nvidia-compute-utils-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-565:amd64.
# Preparing to unpack .../096-libnvidia-encode-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-565.
# Preparing to unpack .../097-nvidia-utils-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-565:amd64.
# Preparing to unpack .../098-libnvidia-cfg1-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../099-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../100-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../101-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../102-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../103-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../104-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../105-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-565.
# Preparing to unpack .../106-xserver-xorg-video-nvidia-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-565:amd64.
# Preparing to unpack .../107-libnvidia-fbc1-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-565.
# Preparing to unpack .../108-nvidia-driver-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-565.
# Preparing to unpack .../109-cuda-drivers-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking cuda-drivers-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../110-cuda-drivers_565.57.01-0ubuntu1_amd64.deb ...
# ...
# Selecting previously unselected package cuda-demo-suite-10-2.
# Preparing to unpack .../112-cuda-demo-suite-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-10-2.
# Preparing to unpack .../113-cuda-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-10-2 (10.2.89-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../114-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../115-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../116-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../117-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../118-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../119-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../120-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../121-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../122-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../123-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../124-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../125-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../126-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../127-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../128-nvidia-prime_0.8.17.1_all.deb ...
# Unpacking nvidia-prime (0.8.17.1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../129-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../130-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../131-nvidia-settings_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (565.57.01-0ubuntu1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../132-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../133-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../134-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../135-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../136-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Setting up libxmu-headers (2:1.1.3-3) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up libnvidia-common-565 (565.57.01-0ubuntu1) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libnvidia-cfg1-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up nvidia-prime (0.8.17.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up nvidia-kernel-source-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-firmware-565-565.57.01 (565.57.01-0ubuntu1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libnvidia-fbc1-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libnvidia-extra-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up nvidia-modprobe (565.57.01-0ubuntu1) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-license-10-2 (10.2.89-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up nvidia-kernel-common-565 (565.57.01-0ubuntu1) ...
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-hibernate.service → /lib/systemd/system/nvidia-hibernate.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-suspend.service → /lib/systemd/system/nvidia-suspend.service.
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up cuda-nvdisasm-10-2 (10.2.89-1) ...
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-nvgraph-10-2 (10.2.89-1) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up cuda-nvvp-10-2 (10.2.89-1) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up cuda-misc-headers-10-2 (10.2.89-1) ...
# Setting up cuda-cusolver-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-10-2 (10.2.89-1) ...
# Setting up cuda-nvprune-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-compute-10-2 (10.2.89-1) ...
# Setting up cuda-memcheck-10-2 (10.2.89-1) ...
# Setting up nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up cuda-cudart-10-2 (10.2.89-1) ...
# Setting up libcublas10 (10.2.2.89-1) ...
# Setting up cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up cuda-cusparse-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-10-2 (10.2.89-1) ...
# Setting up cuda-nvcc-10-2 (10.2.89-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-3) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up cuda-nsight-systems-10-2 (10.2.89-1) ...
# Setting up cuda-nvprof-10-2 (10.2.89-1) ...
# Setting up cuda-curand-10-2 (10.2.89-1) ...
# Setting up cuda-cuobjdump-10-2 (10.2.89-1) ...
# Setting up cuda-nvml-dev-10-2 (10.2.89-1) ...
# Setting up libcublas-dev (10.2.2.89-1) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up cuda-nvtx-10-2 (10.2.89-1) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Setting up cuda-driver-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-10-2 (10.2.89-1) ...
# Setting up cuda-cudart-dev-10-2 (10.2.89-1) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Setting up cuda-npp-10-2 (10.2.89-1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up cuda-cupti-10-2 (10.2.89-1) ...
# Setting up cuda-cufft-10-2 (10.2.89-1) ...
# Setting up cuda-cupti-dev-10-2 (10.2.89-1) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up cuda-curand-dev-10-2 (10.2.89-1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up nvidia-settings (565.57.01-0ubuntu1) ...
# Setting up cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up cuda-cufft-dev-10-2 (10.2.89-1) ...
# Setting up cuda-gdb-10-2 (10.2.89-1) ...
# Setting up cuda-command-line-tools-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Setting up cuda-compiler-10-2 (10.2.89-1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-npp-dev-10-2 (10.2.89-1) ...
# Setting up cuda-libraries-10-2 (10.2.89-1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-libraries-dev-10-2 (10.2.89-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up xserver-xorg-video-nvidia-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-visual-tools-10-2 (10.2.89-1) ...
# Setting up cuda-tools-10-2 (10.2.89-1) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Setting up nvidia-dkms-565 (565.57.01-0ubuntu1) ...
# Loading new nvidia-565.57.01 DKMS files...
# It is likely that 6.1.85+ belongs to a chroot's host
# Building for 5.15.0-128-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-128-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-128-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-128-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-128-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-128-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-128-generic/updates/dkms/
#
# depmod...
# Setting up cuda-samples-10-2 (10.2.89-1) ...
# Setting up cuda-documentation-10-2 (10.2.89-1) ...
# Setting up cuda-toolkit-10-2 (10.2.89-1) ...
# Setting up libnvidia-decode-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-compute-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-gl-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-encode-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up nvidia-utils-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-compute-utils-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-driver-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-drivers-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-drivers (565.57.01-0ubuntu1) ...
# Setting up cuda-runtime-10-2 (10.2.89-1) ...
# Setting up cuda-demo-suite-10-2 (10.2.89-1) ...
# Setting up cuda-10-2 (10.2.89-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# update-alternatives: warning: alternative /usr/local/cuda-12.2 (part of link group cuda) doesn't exist; removing from list of alternatives
# update-alternatives: warning: /etc/alternatives/cuda is dangling; it will be updated with best choice
# update-alternatives: using /usr/local/cuda-10.2 to provide /usr/local/cuda (cuda) in auto mode

# %%
# Installing Pytorch

# !pip install torch==1.11.0 torchvision==0.12.0 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2024.12.14)
# Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.0 MB/s eta 0:00:00
# Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 58.1 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.14.0 requires torch>=1.13.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchvision-0.12.0

# %%
# Installing gcc-7 and g++-7

# !echo "deb http://archive.ubuntu.com/ubuntu focal main universe" > /etc/apt/sources.list
# !apt update
# !apt install gcc-7 g++-7
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-7 1
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-7 1
# Out:
# Get:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Ign:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1,275 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Fetched 12.9 MB in 4s (3,350 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 13 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: file:/var/cuda-repo-10-2-local-10.2.89-440.33.01/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-7 gcc-7-base gcc-8-base libasan4 libcilkrts5 libgcc-7-dev libisl22 libmpx2 libstdc++-7-dev
#   libubsan0
# Suggested packages:
#   gcc-7-locales g++-7-multilib gcc-7-doc gcc-7-multilib libstdc++-7-doc
# The following NEW packages will be installed:
#   cpp-7 g++-7 gcc-7 gcc-7-base gcc-8-base libasan4 libcilkrts5 libgcc-7-dev libisl22 libmpx2
#   libstdc++-7-dev libubsan0
# 0 upgraded, 12 newly installed, 0 to remove and 13 not upgraded.
# Need to get 32.6 MB of archives.
# After this operation, 113 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 gcc-7-base amd64 7.5.0-6ubuntu2 [18.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libisl22 amd64 0.22.1-1 [592 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 cpp-7 amd64 7.5.0-6ubuntu2 [8,588 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libasan4 amd64 7.5.0-6ubuntu2 [358 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libubsan0 amd64 7.5.0-6ubuntu2 [126 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcilkrts5 amd64 7.5.0-6ubuntu2 [42.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 gcc-8-base amd64 8.4.0-3ubuntu2 [18.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmpx2 amd64 8.4.0-3ubuntu2 [11.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgcc-7-dev amd64 7.5.0-6ubuntu2 [2,311 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 gcc-7 amd64 7.5.0-6ubuntu2 [9,381 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 libstdc++-7-dev amd64 7.5.0-6ubuntu2 [1,471 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 g++-7 amd64 7.5.0-6ubuntu2 [9,689 kB]
# Fetched 32.6 MB in 3s (12.6 MB/s)
# Selecting previously unselected package gcc-7-base:amd64.
# (Reading database ... 139952 files and directories currently installed.)
# Preparing to unpack .../00-gcc-7-base_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking gcc-7-base:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libisl22:amd64.
# Preparing to unpack .../01-libisl22_0.22.1-1_amd64.deb ...
# Unpacking libisl22:amd64 (0.22.1-1) ...
# Selecting previously unselected package cpp-7.
# Preparing to unpack .../02-cpp-7_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking cpp-7 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libasan4:amd64.
# Preparing to unpack .../03-libasan4_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libasan4:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libubsan0:amd64.
# Preparing to unpack .../04-libubsan0_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libubsan0:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libcilkrts5:amd64.
# Preparing to unpack .../05-libcilkrts5_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libcilkrts5:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package gcc-8-base:amd64.
# Preparing to unpack .../06-gcc-8-base_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking gcc-8-base:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libmpx2:amd64.
# Preparing to unpack .../07-libmpx2_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking libmpx2:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libgcc-7-dev:amd64.
# Preparing to unpack .../08-libgcc-7-dev_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libgcc-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package gcc-7.
# Preparing to unpack .../09-gcc-7_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking gcc-7 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package libstdc++-7-dev:amd64.
# Preparing to unpack .../10-libstdc++-7-dev_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking libstdc++-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Selecting previously unselected package g++-7.
# Preparing to unpack .../11-g++-7_7.5.0-6ubuntu2_amd64.deb ...
# Unpacking g++-7 (7.5.0-6ubuntu2) ...
# Setting up gcc-7-base:amd64 (7.5.0-6ubuntu2) ...
# Setting up libasan4:amd64 (7.5.0-6ubuntu2) ...
# Setting up gcc-8-base:amd64 (8.4.0-3ubuntu2) ...
# Setting up libmpx2:amd64 (8.4.0-3ubuntu2) ...
# Setting up libcilkrts5:amd64 (7.5.0-6ubuntu2) ...
# Setting up libubsan0:amd64 (7.5.0-6ubuntu2) ...
# Setting up libisl22:amd64 (0.22.1-1) ...
# Setting up cpp-7 (7.5.0-6ubuntu2) ...
# Setting up libgcc-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Setting up libstdc++-7-dev:amd64 (7.5.0-6ubuntu2) ...
# Setting up gcc-7 (7.5.0-6ubuntu2) ...
# Setting up g++-7 (7.5.0-6ubuntu2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# update-alternatives: using /usr/bin/g++-7 to provide /usr/bin/g++ (g++) in auto mode
# update-alternatives: using /usr/bin/gcc-7 to provide /usr/bin/gcc (gcc) in auto mode

# %%
# Installing MinkowskiEngine

# !apt-get install libopenblas-dev
# !pip install git+https://github.com/NVIDIA/MinkowskiEngine.git -v
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting git+https://github.com/NVIDIA/MinkowskiEngine.git
#   Cloning https://github.com/NVIDIA/MinkowskiEngine.git to /tmp/pip-req-build-dj9kx61n
#   Running command git version
#   git version 2.34.1
#   Running command git clone --filter=blob:none https://github.com/NVIDIA/MinkowskiEngine.git /tmp/pip-req-build-dj9kx61n
#   Cloning into '/tmp/pip-req-build-dj9kx61n'...
#   Updating files:   0% (2/244)
#   Updating files:   1% (3/244)
#   Updating files:   2% (5/244)
#   Updating files:   3% (8/244)
#   Updating files:   4% (10/244)
#   Updating files:   5% (13/244)
#   Updating files:   6% (15/244)
#   Updating files:   7% (18/244)
#   Updating files:   8% (20/244)
#   Updating files:   9% (22/244)
#   Updating files:  10% (25/244)
#   Updating files:  11% (27/244)
#   Updating files:  12% (30/244)
#   Updating files:  13% (32/244)
#   Updating files:  14% (35/244)
#   Updating files:  15% (37/244)
#   Updating files:  16% (40/244)
#   Updating files:  17% (42/244)
#   Updating files:  18% (44/244)
#   Updating files:  19% (47/244)
#   Updating files:  20% (49/244)
#   Updating files:  21% (52/244)
#   Updating files:  22% (54/244)
#   Updating files:  23% (57/244)
#   Updating files:  24% (59/244)
#   Updating files:  25% (61/244)
#   Updating files:  26% (64/244)
#   Updating files:  27% (66/244)
#   Updating files:  28% (69/244)
#   Updating files:  29% (71/244)
#   Updating files:  30% (74/244)
#   Updating files:  31% (76/244)
#   Updating files:  32% (79/244)
#   Updating files:  33% (81/244)
#   Updating files:  34% (83/244)
#   Updating files:  35% (86/244)
#   Updating files:  36% (88/244)
#   Updating files:  37% (91/244)
#   Updating files:  38% (93/244)
#   Updating files:  39% (96/244)
#   Updating files:  40% (98/244)
#   Updating files:  41% (101/244)
#   Updating files:  42% (103/244)
#   Updating files:  43% (105/244)
#   Updating files:  44% (108/244)
#   Updating files:  45% (110/244)
#   Updating files:  46% (113/244)
#   Updating files:  47% (115/244)
#   Updating files:  48% (118/244)
#   Updating files:  49% (120/244)
#   Updating files:  50% (122/244)
#   Updating files:  51% (125/244)
#   Updating files:  52% (127/244)
#   Updating files:  53% (130/244)
#   Updating files:  54% (132/244)
#   Updating files:  55% (135/244)
#   Updating files:  56% (137/244)
#   Updating files:  57% (140/244)
#   Updating files:  58% (142/244)
#   Updating files:  59% (144/244)
#   Updating files:  60% (147/244)
#   Updating files:  61% (149/244)
#   Updating files:  62% (152/244)
#   Updating files:  63% (154/244)
#   Updating files:  64% (157/244)
#   Updating files:  65% (159/244)
#   Updating files:  66% (162/244)
#   Updating files:  67% (164/244)
#   Updating files:  68% (166/244)
#   Updating files:  69% (169/244)
#   Updating files:  70% (171/244)
#   Updating files:  71% (174/244)
#   Updating files:  72% (176/244)
#   Updating files:  73% (179/244)
#   Updating files:  74% (181/244)
#   Updating files:  75% (183/244)
#   Updating files:  76% (186/244)
#   Updating files:  77% (188/244)
#   Updating files:  78% (191/244)
#   Updating files:  79% (193/244)
#   Updating files:  80% (196/244)
#   Updating files:  81% (198/244)
#   Updating files:  82% (201/244)
#   Updating files:  83% (203/244)
#   Updating files:  84% (205/244)
#   Updating files:  85% (208/244)
#   Updating files:  86% (210/244)
#   Updating files:  87% (213/244)
#   Updating files:  88% (215/244)
#   Updating files:  89% (218/244)
#   Updating files:  90% (220/244)
#   Updating files:  91% (223/244)
#   Updating files:  92% (225/244)
#   Updating files:  93% (227/244)
#   Updating files:  94% (230/244)
#   Updating files:  95% (232/244)
#   Updating files:  96% (235/244)
#   Updating files:  97% (237/244)
#   Updating files:  98% (240/244)
#   Updating files:  99% (242/244)
#   Updating files: 100% (244/244)
#   Updating files: 100% (244/244), done.
#   Running command git rev-parse HEAD
#   02fc608bea4c0549b0a7b00ca1bf15dee4a0b228
#   Resolved https://github.com/NVIDIA/MinkowskiEngine.git to commit 02fc608bea4c0549b0a7b00ca1bf15dee4a0b228
#   Running command git rev-parse HEAD
#   02fc608bea4c0549b0a7b00ca1bf15dee4a0b228
#   Running command python setup.py egg_info
#   WARNING: Skipping MinkowskiEngine as it is not installed.
#   /tmp/pip-req-build-dj9kx61n/setup.py:201: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     import numpy.distutils.system_info as sysinfo
#   --------------------------------
#   | CUDA compilation set         |
#   --------------------------------
#
#   Using BLAS=openblas
#   Using the default compiler
#   running egg_info
#   creating /tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info
#   writing /tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/SOURCES.txt'
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:387: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   reading manifest file '/tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-uep57nri/MinkowskiEngine.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from MinkowskiEngine==0.5.4) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from MinkowskiEngine==0.5.4) (1.26.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->MinkowskiEngine==0.5.4) (4.12.2)
# Building wheels for collected packages: MinkowskiEngine
#   Running command python setup.py bdist_wheel
#   WARNING: Skipping MinkowskiEngine as it is not installed.
#   --------------------------------
#   | CUDA compilation set         |
#   --------------------------------
#   /tmp/pip-req-build-dj9kx61n/setup.py:201: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     import numpy.distutils.system_info as sysinfo
#
#   Using BLAS=openblas
#   Using the default compiler
#   running bdist_wheel
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:387: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-cpython-310
#   creating build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiKernelGenerator.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiUnion.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiTensorField.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/sparse_matrix_functions.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/__init__.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiInterpolation.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiNonlinearity.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiSparseTensor.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/diagnostics.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiOps.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiChannelwiseConvolution.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiNetwork.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiTensor.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiBroadcast.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiCommon.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiNormalization.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiConvolution.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiFunctional.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiPruning.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiPooling.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   copying ./MinkowskiEngine/MinkowskiCoordinateManager.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine
#   creating build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/gradcheck.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/quantization.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/__init__.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/coords.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/init.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/collation.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   copying ./MinkowskiEngine/utils/summary.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils
#   creating build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules
#   copying ./MinkowskiEngine/modules/__init__.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules
#   copying ./MinkowskiEngine/modules/resnet_block.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules
#   copying ./MinkowskiEngine/modules/senet_block.py -> build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules
#   running build_ext
#   building 'MinkowskiEngineBackend._C' extension
#   INFO: C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC
#
#   creating build/temp.linux-x86_64-cpython-310
#   creating build/temp.linux-x86_64-cpython-310/tmp
#   creating build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n
#   creating build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src
#   creating build/temp.linux-x86_64-cpython-310/pybind
#   INFO: compile options: '-I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/tmp/pip-req-build-dj9kx61n/src -I/tmp/pip-req-build-dj9kx61n/src/3rdparty -I/usr/include/python3.10 -c'
#   extra options: 'cxx nvcc'
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/broadcast_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/broadcast_kernel.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/convolution_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/convolution_kernel.cu
#   /tmp/pip-req-build-dj9kx61n/src/convolution_kernel.cu(334): warning: integer conversion resulted in a change of sign
#
#   /tmp/pip-req-build-dj9kx61n/src/convolution_kernel.cu(573): warning: integer conversion resulted in a change of sign
#
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/convolution_transpose_gpu.cu
#   /tmp/pip-req-build-dj9kx61n/src/convolution_kernel.cu(334): warning: integer conversion resulted in a change of sign
#
#   /tmp/pip-req-build-dj9kx61n/src/convolution_kernel.cu(573): warning: integer conversion resulted in a change of sign
#
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(625): here
#               instantiation of "minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::self_type minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_region(minkowski::cpu_kernel_region<coordinate_type> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_type &) const [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(2460): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(625): here
#               instantiation of "minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::self_type minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_region(minkowski::cpu_kernel_region<coordinate_type> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_type &) const [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(2460): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(625): here
#               instantiation of "minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::self_type minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_region(minkowski::cpu_kernel_region<coordinate_type> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_type &) const [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(2460): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(625): here
#               instantiation of "minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::self_type minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_region(minkowski::cpu_kernel_region<coordinate_type> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator>::stride_type &) const [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.cu(2460): here
#
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_cpu.hpp(58): warning: variable "float_type" was declared but never referenced
#             detected during:
#               instantiation of "std::pair<at::Tensor, at::Tensor> minkowski::CoordinateMapCPU<coordinate_type, TemplatedAllocator>::field_map(const coordinate_field_type *, minkowski::CoordinateMapCPU<coordinate_type, TemplatedAllocator>::size_type) const [with coordinate_type=int32_t, TemplatedAllocator=std::allocator, coordinate_field_type=float]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(329): here
#               instantiation of "std::pair<at::Tensor, at::Tensor> minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::field_to_sparse_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=std::allocator, CoordinateMapType=minkowski::CoordinateMapCPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(1451): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=std::allocator, CoordinateMapType=minkowski::CoordinateMapCPU]"
#   (1451): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(205): here
#               instantiation of "minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>> minkowski::detail::kernel_map_functor<coordinate_type, TemplatedAllocator, minkowski::CoordinateMapGPU, minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>>>::operator()(const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, minkowski::CUDAKernelMapMode::Mode, minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(753): here
#               instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(205): here
#               instantiation of "minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>> minkowski::detail::kernel_map_functor<coordinate_type, TemplatedAllocator, minkowski::CoordinateMapGPU, minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>>>::operator()(const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, minkowski::CUDAKernelMapMode::Mode, minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(753): here
#               instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(205): here
#               instantiation of "minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>> minkowski::detail::kernel_map_functor<coordinate_type, TemplatedAllocator, minkowski::CoordinateMapGPU, minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>>>::operator()(const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, minkowski::CUDAKernelMapMode::Mode, minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(753): here
#               instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp(428): warning: calling a __host__ function from a __host__ __device__ function is not allowed
#             detected during:
#               instantiation of "minkowski::gpu_kernel_region<coordinate_type>::gpu_kernel_region(const minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(205): here
#               instantiation of "minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>> minkowski::detail::kernel_map_functor<coordinate_type, TemplatedAllocator, minkowski::CoordinateMapGPU, minkowski::gpu_kernel_map<minkowski::type_wrapper<uint32_t, int32_t, float>::index_type, TemplatedAllocator<char>>>::operator()(const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, const minkowski::CoordinateMapGPU<coordinate_type, TemplatedAllocator> &, minkowski::CUDAKernelMapMode::Mode, minkowski::cpu_kernel_region<coordinate_type> &) [with coordinate_type=int32_t, TemplatedAllocator=minkowski::detail::default_allocator]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(753): here
#               instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, __nv_bool, __nv_bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::c10_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(404): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, bool, bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=std::allocator, CoordinateMapType=minkowski::CoordinateMapCPU]"
#   (1451): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, bool, bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::default_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(401): here
#
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp(717): warning: returning reference to local temporary
#             detected during instantiation of "const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type &minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapKey *, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, const minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type &, minkowski::RegionType::Type, const at::Tensor &, bool, bool) [with coordinate_type=int32_t, coordinate_field_type=float, TemplatedAllocator=minkowski::detail::c10_allocator, CoordinateMapType=minkowski::CoordinateMapGPU]"
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu(404): here
#
#   INFO: x86_64-linux-gnu-gcc: /tmp/pip-req-build-dj9kx61n/src/direct_max_pool.cpp
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp: In instantiation of ‘const kernel_map_type& minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey*, const minkowski::CoordinateMapKey*, const stride_type&, const stride_type&, const stride_type&, minkowski::RegionType::Type, const at::Tensor&, bool, bool) [with coordinate_type = int; coordinate_field_type = float; TemplatedAllocator = std::allocator; CoordinateMapType = minkowski::CoordinateMapCPU; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type = minkowski::cpu_kernel_map; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type = std::vector<unsigned int, std::allocator<unsigned int> >]’:
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp:1451:16:   required from here
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp:717:260: warning: returning reference to temporary [-Wreturn-local-addr]
#          return detail::empty_map_functor<coordinate_type, TemplatedAllocator,
#                                                                                                                                                                                                                                                                       ^
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp: In instantiation of ‘const kernel_map_type& minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey*, const minkowski::CoordinateMapKey*, const stride_type&, const stride_type&, const stride_type&, minkowski::RegionType::Type, const at::Tensor&, bool, bool) [with coordinate_type = int; coordinate_field_type = float; TemplatedAllocator = minkowski::detail::default_allocator; CoordinateMapType = minkowski::CoordinateMapGPU; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type = minkowski::gpu_kernel_map<unsigned int, minkowski::detail::default_allocator<char> >; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type = std::vector<unsigned int, std::allocator<unsigned int> >]’:
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu:401:16:   required from here
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp:717:260: warning: returning reference to temporary [-Wreturn-local-addr]
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp: In instantiation of ‘const kernel_map_type& minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map(const minkowski::CoordinateMapKey*, const minkowski::CoordinateMapKey*, const stride_type&, const stride_type&, const stride_type&, minkowski::RegionType::Type, const at::Tensor&, bool, bool) [with coordinate_type = int; coordinate_field_type = float; TemplatedAllocator = minkowski::detail::c10_allocator; CoordinateMapType = minkowski::CoordinateMapGPU; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::kernel_map_type = minkowski::gpu_kernel_map<unsigned int, minkowski::detail::c10_allocator<char> >; minkowski::CoordinateMapManager<coordinate_type, coordinate_field_type, TemplatedAllocator, CoordinateMapType>::stride_type = std::vector<unsigned int, std::allocator<unsigned int> >]’:
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cu:404:16:   required from here
#   /tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.cpp:717:260: warning: returning reference to temporary [-Wreturn-local-addr]
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/global_pooling_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/gpu.cu
#   /tmp/pip-req-build-dj9kx61n/src/gpu.cu(104): warning: function "minkowski::format_size" was declared but never referenced
#
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/interpolation_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/local_pooling_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/local_pooling_transpose_gpu.cu
#   INFO: x86_64-linux-gnu-gcc: /tmp/pip-req-build-dj9kx61n/src/math_functions_cpu.cpp
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/math_functions_gpu.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/pooling_avg_kernel.cu
#   /tmp/pip-req-build-dj9kx61n/src/pooling_avg_kernel.cu(146): warning: variable "is_int64" was declared but never referenced
#
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/pooling_max_kernel.cu
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/pruning_gpu.cu
#   INFO: x86_64-linux-gnu-gcc: /tmp/pip-req-build-dj9kx61n/src/quantization.cpp
#   In file included from /tmp/pip-req-build-dj9kx61n/src/allocators.cuh:39,
#                    from /tmp/pip-req-build-dj9kx61n/src/kernel_region.hpp:40,
#                    from /tmp/pip-req-build-dj9kx61n/src/coordinate_map.hpp:30,
#                    from /tmp/pip-req-build-dj9kx61n/src/coordinate_map_cpu.hpp:28,
#                    from /tmp/pip-req-build-dj9kx61n/src/quantization.cpp:32:
#   /tmp/pip-req-build-dj9kx61n/src/gpu.cuh:149: warning: "THRUST_CHECK" redefined
#     149 | #define THRUST_CHECK(condition)                                                \
#         |
#   In file included from /tmp/pip-req-build-dj9kx61n/src/coordinate.hpp:30,
#                    from /tmp/pip-req-build-dj9kx61n/src/coordinate_map.hpp:29,
#                    from /tmp/pip-req-build-dj9kx61n/src/coordinate_map_cpu.hpp:28,
#                    from /tmp/pip-req-build-dj9kx61n/src/quantization.cpp:32:
#   /tmp/pip-req-build-dj9kx61n/src/utils.hpp:169: note: this is the location of the previous definition
#     169 | #define THRUST_CHECK(condition) condition;
#         |
#   /tmp/pip-req-build-dj9kx61n/src/quantization.cpp: In function ‘std::vector<std::vector<int, std::allocator<int> > > minkowski::quantize_label(const int*, const int*, int, int, int)’:
#   /tmp/pip-req-build-dj9kx61n/src/quantization.cpp:177:16: warning: variable ‘it’ set but not used [-Wunused-but-set-variable]
#     177 |     const auto it = map.find(key);
#         |                ^~
#   INFO: nvcc: /tmp/pip-req-build-dj9kx61n/src/spmm.cu
#   INFO: nvcc: pybind/minkowski.cu
#   /tmp/pip-req-build-dj9kx61n/src/spmm.cu(93): warning: variable "is_int64" was declared but never referenced
#
#   /tmp/pip-req-build-dj9kx61n/src/spmm.cu(355): warning: variable "is_int64" was declared but never referenced
#
#   /tmp/pip-req-build-dj9kx61n/src/spmm.cu(464): warning: variable "num_unique_keys" was set but never used
#             detected during instantiation of "std::vector<at::Tensor, std::allocator<at::Tensor>> minkowski::coo_spmm_average<th_int_type>(const at::Tensor &, const at::Tensor &, int64_t, int64_t, const at::Tensor &, int64_t) [with th_int_type=int32_t]"
#   (592): here
#
#   /tmp/pip-req-build-dj9kx61n/src/spmm.cu(464): warning: variable "num_unique_keys" was set but never used
#             detected during instantiation of "std::vector<at::Tensor, std::allocator<at::Tensor>> minkowski::coo_spmm_average<th_int_type>(const at::Tensor &, const at::Tensor &, int64_t, int64_t, const at::Tensor &, int64_t) [with th_int_type=int32_t]"
#   (592): here
#
#   creating build/lib.linux-x86_64-cpython-310/MinkowskiEngineBackend
#   INFO: x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/broadcast_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/broadcast_kernel.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/convolution_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/convolution_kernel.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/convolution_transpose_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/coordinate_map_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/coordinate_map_manager.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/direct_max_pool.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/global_pooling_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/interpolation_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/local_pooling_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/local_pooling_transpose_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/math_functions_cpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/math_functions_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/pooling_avg_kernel.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/pooling_max_kernel.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/pruning_gpu.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/quantization.o build/temp.linux-x86_64-cpython-310/tmp/pip-req-build-dj9kx61n/src/spmm.o build/temp.linux-x86_64-cpython-310/pybind/minkowski.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lcusparse -lopenblas -lopenblas -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/MinkowskiEngineBackend/_C.cpython-310-x86_64-linux-gnu.so
#   /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiKernelGenerator.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiUnion.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiTensorField.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/sparse_matrix_functions.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/__init__.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   creating build/bdist.linux-x86_64/wheel/MinkowskiEngine/modules
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules/__init__.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/modules
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules/resnet_block.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/modules
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/modules/senet_block.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/modules
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiInterpolation.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiNonlinearity.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiSparseTensor.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/diagnostics.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiOps.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiChannelwiseConvolution.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiNetwork.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiTensor.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiBroadcast.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   creating build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/gradcheck.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/quantization.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/__init__.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/coords.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/init.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/collation.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/utils/summary.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine/utils
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiCommon.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiNormalization.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiConvolution.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiFunctional.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiPruning.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiPooling.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngine/MinkowskiCoordinateManager.py -> build/bdist.linux-x86_64/wheel/MinkowskiEngine
#   creating build/bdist.linux-x86_64/wheel/MinkowskiEngineBackend
#   copying build/lib.linux-x86_64-cpython-310/MinkowskiEngineBackend/_C.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel/MinkowskiEngineBackend
#   running install_egg_info
#   running egg_info
#   creating MinkowskiEngine.egg-info
#   writing MinkowskiEngine.egg-info/PKG-INFO
#   writing dependency_links to MinkowskiEngine.egg-info/dependency_links.txt
#   writing requirements to MinkowskiEngine.egg-info/requires.txt
#   writing top-level names to MinkowskiEngine.egg-info/top_level.txt
#   writing manifest file 'MinkowskiEngine.egg-info/SOURCES.txt'
#   reading manifest file 'MinkowskiEngine.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   writing manifest file 'MinkowskiEngine.egg-info/SOURCES.txt'
#   Copying MinkowskiEngine.egg-info to build/bdist.linux-x86_64/wheel/MinkowskiEngine-0.5.4-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/MinkowskiEngine-0.5.4.dist-info/WHEEL
#   creating '/tmp/pip-wheel-fnizre_b/MinkowskiEngine-0.5.4-cp310-cp310-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'MinkowskiEngine/MinkowskiBroadcast.py'
#   adding 'MinkowskiEngine/MinkowskiChannelwiseConvolution.py'
#   adding 'MinkowskiEngine/MinkowskiCommon.py'
#   adding 'MinkowskiEngine/MinkowskiConvolution.py'
#   adding 'MinkowskiEngine/MinkowskiCoordinateManager.py'
#   adding 'MinkowskiEngine/MinkowskiFunctional.py'
#   adding 'MinkowskiEngine/MinkowskiInterpolation.py'
#   adding 'MinkowskiEngine/MinkowskiKernelGenerator.py'
#   adding 'MinkowskiEngine/MinkowskiNetwork.py'
#   adding 'MinkowskiEngine/MinkowskiNonlinearity.py'
#   adding 'MinkowskiEngine/MinkowskiNormalization.py'
#   adding 'MinkowskiEngine/MinkowskiOps.py'
#   adding 'MinkowskiEngine/MinkowskiPooling.py'
#   adding 'MinkowskiEngine/MinkowskiPruning.py'
#   adding 'MinkowskiEngine/MinkowskiSparseTensor.py'
#   adding 'MinkowskiEngine/MinkowskiTensor.py'
#   adding 'MinkowskiEngine/MinkowskiTensorField.py'
#   adding 'MinkowskiEngine/MinkowskiUnion.py'
#   adding 'MinkowskiEngine/__init__.py'
#   adding 'MinkowskiEngine/diagnostics.py'
#   adding 'MinkowskiEngine/sparse_matrix_functions.py'
#   adding 'MinkowskiEngine/modules/__init__.py'
#   adding 'MinkowskiEngine/modules/resnet_block.py'
#   adding 'MinkowskiEngine/modules/senet_block.py'
#   adding 'MinkowskiEngine/utils/__init__.py'
#   adding 'MinkowskiEngine/utils/collation.py'
#   adding 'MinkowskiEngine/utils/coords.py'
#   adding 'MinkowskiEngine/utils/gradcheck.py'
#   adding 'MinkowskiEngine/utils/init.py'
#   adding 'MinkowskiEngine/utils/quantization.py'
#   adding 'MinkowskiEngine/utils/summary.py'
#   adding 'MinkowskiEngineBackend/_C.cpython-310-x86_64-linux-gnu.so'
#   adding 'MinkowskiEngine-0.5.4.dist-info/LICENSE'
#   adding 'MinkowskiEngine-0.5.4.dist-info/METADATA'
#   adding 'MinkowskiEngine-0.5.4.dist-info/WHEEL'
#   adding 'MinkowskiEngine-0.5.4.dist-info/top_level.txt'
#   adding 'MinkowskiEngine-0.5.4.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for MinkowskiEngine (setup.py) ... done
#   Created wheel for MinkowskiEngine: filename=MinkowskiEngine-0.5.4-cp310-cp310-linux_x86_64.whl size=6897671 sha256=234e46990eb9c821604fd78e99a1757cffc77da06c9ab556488dc7f0534eca16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ljquty3_/wheels/22/93/6c/b071895b434e3b9d3057d66eafce1d2040a594d5ba27136890
# Successfully built MinkowskiEngine
# Installing collected packages: MinkowskiEngine
# Successfully installed MinkowskiEngine-0.5.4

# %%
import torch
print(f"Is CUDA available in torch?: {torch.cuda.is_available()}")
import MinkowskiEngine as ME
print(f"Is CUDA available in MinkowskiEngine?: {ME.is_cuda_available()}")
ME.print_diagnostics()
# Out:
# Is CUDA available in torch?: True
# Is CUDA available in MinkowskiEngine?: True
# ==========System==========
# Linux-6.1.85+-x86_64-with-glibc2.35
# 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# ==========Pytorch==========
# 1.11.0+cu102
# torch.cuda.is_available(): True
# ==========NVIDIA-SMI==========
# Driver Version 535.104.05
# CUDA Version 12.2
# VBIOS Version 90.04.A7.00.01
# Image Version G183.0200.00.02
# GSP Firmware Version N/A
# ==========NVCC==========
# ==========CC==========
# ==========MinkowskiEngine==========
# 0.5.4
# MinkowskiEngine compiled with CUDA Support: True
# NVCC version MinkowskiEngine is compiled: 10020
# CUDART version MinkowskiEngine is compiled: 10020

# %% [markdown]
# # Download dataset từ kaggle

# %%
import os

# Create Kaggle folder
os.makedirs("/root/.kaggle", exist_ok=True)

# Move the kaggle.json file to the correct location
# !mv kaggle.json /root/.kaggle/

# Set permissions for the file
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# Replace 'dataset-name' with the actual dataset URL segment
# !kaggle datasets download -d hphat9824/vn-moto-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hphat9824/vn-moto-dataset
# License(s): apache-2.0
# Downloading vn-moto-dataset.zip to /content
# 100% 2.05G/2.06G [00:34<00:00, 131MB/s]
# 100% 2.06G/2.06G [00:34<00:00, 64.4MB/s]

# %%
# !kaggle datasets download -d hphat9824/tiny-moto-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hphat9824/tiny-moto-dataset
# License(s): unknown
# Downloading tiny-moto-dataset.zip to /content
#  96% 217M/226M [00:03<00:00, 63.4MB/s]
# 100% 226M/226M [00:03<00:00, 77.4MB/s]

# %%
# !unzip tiny-moto-dataset.zip -d /content/tiny-moto-dataset
# Out:
# Archive:  tiny-moto-dataset.zip
#   inflating: /content/tiny-moto-dataset/Honda/22520193-22520234-22520363.Honda.110.png
#   inflating: /content/tiny-moto-dataset/Honda/22520193-22520234-22520363.Honda.71.png
#   inflating: /content/tiny-moto-dataset/Honda/22520193-22520234-22520363.Honda.82.png
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.471.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.472.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.473.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.474.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.475.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.476.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.477.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.478.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.479.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.480.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.481.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.482.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.483.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.484.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.485.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.486.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.487.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.488.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.489.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.490.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.491.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.492.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.493.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.494.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.495.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.496.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.497.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.498.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.499.jpeg
#   inflating: /content/tiny-moto-dataset/Honda/22520968-22520996-22520999-22520929-22521373.Honda.500.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.34.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.35.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.36.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.37.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.38.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.39.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.40.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.41.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.42.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.43.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.44.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.45.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.46.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.47.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.48.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.49.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.50.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.51.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.52.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.53.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.54.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.55.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.56.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.57.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.58.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.59.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.60.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.61.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.62.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.63.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.64.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.65.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.66.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.67.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.68.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.69.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.7.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.70.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.71.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.72.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.73.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.74.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.75.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.76.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.77.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.78.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.79.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.80.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.81.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.82.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.83.jpg
#   inflating: /content/tiny-moto-dataset/Honda/22521402.Honda.84.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.11.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.14.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.22.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.23.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.31.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.34.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.4.jpg
#   inflating: /content/tiny-moto-dataset/Others/21520282-21520569-21521869.Others.9.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.11.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.12.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.13.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.14.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.15.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.16.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.17.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.18.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.19.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.20.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.21.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.22.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.24.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.25.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.31.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.32.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.40.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.41.png
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.42.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.43.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.56.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.57.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.58.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.60.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.61.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.62.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.63.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.64.jpeg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.66.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.8.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522028-21522057.Others.9.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.61.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.62.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.65.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.66.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.69.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.71.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.72.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.80.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.87.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.88.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.89.jpg
#   inflating: /content/tiny-moto-dataset/Others/21522446-21522243.Others.95.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.1.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.10.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.11.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.12.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.13.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.14.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.15.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.16.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.17.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.18.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.19.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.2.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.20.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.21.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.22.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.23.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.24.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.25.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.26.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.27.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.28.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.29.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.3.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.30.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.31.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.32.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.33.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.34.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.35.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.36.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.37.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.38.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.39.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.4.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.40.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.41.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.42.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.43.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.44.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.45.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.46.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.47.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.48.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.49.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.5.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.50.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.51.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.52.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.53.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.54.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.55.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.56.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.57.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.58.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.59.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.6.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.60.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.61.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.62.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.63.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.64.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.65.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.66.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.67.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.68.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.69.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.7.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.8.jpg
#   inflating: /content/tiny-moto-dataset/Others/22521293-22520105-22521624.Others.9.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.131.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.133.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.140.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.141.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.142.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.143.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.147.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.154.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.157.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21521007-21522629.Suzuki.164.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.27.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.28.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.29.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.30.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.31.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.32.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.33.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.34.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.35.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.36.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.37.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.38.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.39.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.40.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.41.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.42.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.43.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.44.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.45.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.46.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.47.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.48.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.49.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.50.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.51.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.52.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.53.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.54.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.55.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.56.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.57.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.58.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.59.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/21522446-21522243.Suzuki.60.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.136.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.164.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.199.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.22.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.242.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.274.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.328.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.honda.62.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.112.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.113.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.114.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.115.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.116.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.117.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.118.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.119.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.120.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.121.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.122.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.123.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.124.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.125.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.127.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.130.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.131.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.132.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.133.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.135.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.136.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.138.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.139.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.141.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.142.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.143.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.144.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.148.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.149.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.151.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.152.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.153.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.154.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.155.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.156.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.159.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.160.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.162.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.164.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.166.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.167.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.170.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.171.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.172.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.173.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.175.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.177.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.179.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.180.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.181.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.182.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.183.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.185.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.186.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.187.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.188.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.189.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.190.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.191.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.193.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.194.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.195.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.198.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.199.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.200.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.202.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.203.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.204.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.205.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.206.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.208.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.210.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.211.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.213.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.214.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.216.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.217.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.218.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.219.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.220.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.222.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.223.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.225.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.226.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.227.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki.229.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.103.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.104.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.106.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.107.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.109.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.110.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.111.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.112.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.113.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.118.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.121.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.122.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.123.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.125.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.126.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.127.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.129.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.130.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.133.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.134.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.135.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.137.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.139.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.140.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.143.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.144.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.145.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.146.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.147.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.150.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.151.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.152.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.153.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.155.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.156.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.157.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.158.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.160.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.161.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.162.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.163.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.164.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.166.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.168.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.170.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.171.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.173.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.174.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.176.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.177.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.178.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.179.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.180.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.181.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.182.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.184.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.187.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.189.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.191.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.192.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.193.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.194.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.195.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.196.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.197.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.199.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.201.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.202.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.203.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.204.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.205.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.208.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.209.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.210.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520003-22520010-22520398-22520630-22520053.suzuki2.211.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.115.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.116.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.117.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.118.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.122.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.124.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.125.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.127.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.128.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.129.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.130.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.133.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.134.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.135.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.136.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.137.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.138.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.141.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.145.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.147.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.149.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.150.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.151.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.152.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.153.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.154.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.155.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.157.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.158.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.159.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520356-22520424-22520460-22520467-22521129.Suzuki.160.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.238.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.239.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.240.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.241.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.242.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.243.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.244.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.245.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.247.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.248.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.249.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.250.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22520896-22520926-22521627.Suzuki.251.png
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.1.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.3.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.5.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.6.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.7.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.8.jpg
#   inflating: /content/tiny-moto-dataset/Suzuki/22521184.Suzuki.9.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.496.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.497.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.498.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.499.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.500.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.501.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.502.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.503.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.504.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.505.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.506.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.507.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.508.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.509.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.510.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.511.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.512.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.513.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.514.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.515.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.516.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.517.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.518.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.519.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.520.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.521.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.522.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.523.jpg
#   inflating: /content/tiny-moto-dataset/VinFast/22520968-22520996-22520999-22520929-22521373.VinFast.524.jpg
# ...
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.818.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.819.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.820.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.821.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.822.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.823.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.824.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.825.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.826.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.827.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.828.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.829.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.830.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.831.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.832.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.833.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.834.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.835.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.836.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.837.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.838.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.839.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.840.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.841.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.842.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.843.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.844.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.845.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.846.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.847.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.848.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.849.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.850.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.851.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.852.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.853.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.854.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.855.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.856.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.857.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.858.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.859.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.860.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.861.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.862.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.863.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.864.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.865.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.866.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.867.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.868.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.869.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.870.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.871.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.872.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.873.png
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.874.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.875.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.876.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.877.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.878.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.879.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.880.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.881.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.882.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.883.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.884.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.885.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.886.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.887.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.888.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.889.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.890.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.891.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.892.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.893.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.894.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.895.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.896.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.897.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.898.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.899.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.900.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.901.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.902.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.903.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.904.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.905.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.906.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.907.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.908.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.909.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.910.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.911.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.912.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.913.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.914.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.915.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.916.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.917.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.918.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.919.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.920.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.921.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.922.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.923.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.924.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.925.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.926.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.927.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.928.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.929.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.930.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.931.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.932.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.933.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.934.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.935.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.936.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.937.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.938.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.939.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.940.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.941.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.942.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.943.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.944.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.945.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.946.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.947.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.948.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.949.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.950.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.951.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.952.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.953.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.954.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.955.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.956.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.957.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.958.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.959.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.960.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.961.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.962.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22520968-22520996-22520999-22520929-22521373.Yamaha.963.jpg
#   inflating: /content/tiny-moto-dataset/Yamaha/22521184.Yamaha.50.jpg

# %%
# !unzip vn-moto-dataset.zip -d /content/vn-moto-dataset
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.41.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.42.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.43.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.44.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.45.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.46.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.47.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.48.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.49.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.50.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.51.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.52.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.53.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.54.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.55.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.56.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.57.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.58.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.59.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.60.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.61.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.62.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.63.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.64.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.65.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.66.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.67.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.68.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.69.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521005-22520488-22520619.Vinfast.70.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.25.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.30.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.31.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.32.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.33.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.34.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.35.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.36.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.37.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.38.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.41.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.42.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.43.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.44.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.45.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.46.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.47.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.48.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.49.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.50.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521031.VinFast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.1.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.10.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.11.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.12.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.13.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.14.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.15.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.16.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.17.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.18.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.19.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.2.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.20.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.21.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.22.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.23.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.24.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.25.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.26.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.3.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.30.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.4.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.5.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.6.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.7.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.8.png
#   inflating: /content/vn-moto-dataset/VinFast/22521074-22521189-22520725.Vinfast.9.png
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.25.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.30.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.31.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.32.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.33.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.34.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.35.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.36.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.37.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.38.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521184.Vinfast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.0.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.1.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.10.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.11.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.12.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.13.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.14.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.15.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.16.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.17.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.18.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.19.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.2.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.20.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.21.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.22.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.23.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.24.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.25.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.26.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.27.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.28.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.29.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.3.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.30.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.31.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.32.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.33.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.34.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.35.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.36.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.37.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.38.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.39.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.4.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.40.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.41.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.42.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.43.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.44.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.45.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.46.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.47.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.48.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.49.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.5.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.50.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.51.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.52.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.53.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.54.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.55.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.56.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.57.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.58.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.59.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.6.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.60.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.61.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.62.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.63.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.64.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.65.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.66.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.67.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.68.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.69.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.7.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.8.png
#   inflating: /content/vn-moto-dataset/VinFast/22521260-22520125-22521575-22521204.Vinfast.9.png
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.25.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.30.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521266.VinFast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.25.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.30.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.31.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.32.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.33.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.34.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.35.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.36.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.37.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.38.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.41.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.42.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.44.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.45.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.46.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.47.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.48.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.49.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.51.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.52.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.53.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.54.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.55.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.56.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.57.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.58.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.59.png
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.60.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.61.png
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521293-22520105-22521624.VinFast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.12.png
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.17.png
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.25.png
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.28.png
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.29.webp
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.30.png
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.31.webp
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.32.webp
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.33.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.34.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.35.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.36.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.37.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.38.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.41.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.42.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.6.webp
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521309-22521610-22521617-22520240.VinFast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521332.VinFast.31.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521332.VinFast.32.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521332.VinFast.33.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521332.VinFast.34.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521332.VinFast.35.jpeg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.20.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.21.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.22.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.23.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.24.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.25.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.26.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.27.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.28.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.29.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.30.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.31.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.32.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.33.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.34.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.35.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.36.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.37.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.38.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.39.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.40.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.41.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.42.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.43.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.44.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.45.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.46.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.47.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.48.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.49.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.50.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.51.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.52.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.53.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.54.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.55.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.56.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521402.Vinfast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.2.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.3.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.4.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.5.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.6.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.7.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.8.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521623.VinFast.9.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.1.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.10.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.100.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.101.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.102.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.103.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.104.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.105.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.106.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.107.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.108.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.109.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.11.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.110.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.111.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.112.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.113.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.114.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.115.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.116.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.117.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.118.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.119.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.12.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.120.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.121.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.122.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.123.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.124.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.125.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.126.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.127.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.128.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.129.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.13.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.130.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.131.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.132.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.133.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.134.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.135.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.136.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.137.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.138.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.139.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.14.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.140.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.141.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.142.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.143.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.144.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.145.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.146.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.147.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.148.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.149.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.15.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.150.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.151.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.152.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.153.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.154.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.155.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.156.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.157.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.158.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.159.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.16.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.160.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.161.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.162.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.163.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.164.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.165.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.166.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.167.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.168.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.169.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.17.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.170.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.171.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.172.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.173.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.174.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.175.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.176.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.177.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.178.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.179.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.18.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.180.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.181.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.182.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.183.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.184.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.185.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.186.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.187.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.188.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.189.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.19.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.190.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.191.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.192.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.193.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.194.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.195.jpg
#   inflating: /content/vn-moto-dataset/VinFast/22521705-22520777-22520202-22521304-22521716.VinFast.196.jpg
# ...
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.355.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.356.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.357.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.358.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.359.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.36.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.360.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.361.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.362.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.363.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.364.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.365.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.366.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.367.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.368.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.369.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.37.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.370.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.371.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.372.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.373.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.374.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.375.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.376.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.377.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.378.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.379.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.38.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.380.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.381.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.382.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.383.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.384.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.385.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.386.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.387.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.388.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.389.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.39.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.390.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.391.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.392.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.393.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.394.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.395.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.396.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.397.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.398.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.399.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.4.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.40.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.400.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.401.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.402.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.403.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.404.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.405.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.406.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.407.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.408.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.409.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.41.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.410.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.411.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.412.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.413.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.414.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.415.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.416.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.417.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.418.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.419.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.42.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.420.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.421.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.422.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.423.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.424.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.425.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.426.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.427.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.428.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.429.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.43.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.430.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.431.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.432.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.433.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.434.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.44.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.45.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.46.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.47.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.48.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.49.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.5.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.50.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.51.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.52.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.53.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.54.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.55.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.56.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.57.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.58.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.59.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.6.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.60.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.61.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.62.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.63.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.64.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.65.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.66.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.67.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.68.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.69.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.7.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.70.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.71.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.72.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.73.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.74.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.75.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.76.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.77.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.78.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.79.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.8.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.80.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.81.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.82.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.83.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.84.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.85.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.86.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.87.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.88.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.89.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.9.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.90.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.91.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.92.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.93.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.94.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.95.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.96.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.97.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.98.jpg
#   inflating: /content/vn-moto-dataset/Yamaha/22521705-22520777-22520202-22521304-22521716.Yamaha.99.jpg

# %%
# !pip install torch timm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (1.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.27.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.12.14)

# %%
train_images_path = []
train_dir = '/content/vn-moto-dataset'
for subfolder in os.listdir(train_dir):
    if not subfolder.endswith('.txt'):
        for file in os.listdir(os.path.join(train_dir,subfolder)):
            if file.lower().endswith('png') or file.lower().endswith('jpg') or file.lower().endswith('jpeg'):
                train_images_path.append(os.path.join(train_dir,subfolder, file))

# %%
from torch.utils.data import Dataset
from PIL import Image
import cv2
import numpy as np
from timm.models.layers import trunc_normal_,DropPath
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
import argparse
import sys
from tqdm import tqdm
import math
import random
from MinkowskiEngine import SparseTensor
from MinkowskiEngine import (
    MinkowskiConvolution,
    MinkowskiChannelwiseConvolution,
    MinkowskiLinear,
    MinkowskiGELU
)
from MinkowskiOps import (
    to_sparse,
)

# %% [markdown]
# # Data Loader

# %%
class MyDataset(Dataset):
    def __init__(self, images_path, transform = None):
        self.images_path = images_path
        self.transform = transform
        self.valid_images_path = []
        for path in self.images_path:
            img = Image.open(path)
            if img.mode != "P":  # Exclude palette mode
                self.valid_images_path.append(path)
    def __len__(self):
        return len(self.valid_images_path)
    def __getitem__(self, item):
        img = Image.open(self.valid_images_path[item]).convert("RGB")
        if self.transform is not None:
            img = self.transform(img)
        return img

# %% [markdown]
# # ConvNeXt V2

# %% [markdown]
# ## Encoder

# %%
class LayerNorm(nn.Module):
    r""" LayerNorm that supports two data formats: channels_last (default) or channels_first.
    The ordering of the dimensions in the inputs. channels_last corresponds to inputs with
    shape (batch_size, height, width, channels) while channels_first corresponds to inputs
    with shape (batch_size, channels, height, width).
    """

    def __init__(self, normalized_shape, eps=1e-6, data_format="channels_last"):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(normalized_shape), requires_grad=True)
        self.bias = nn.Parameter(torch.zeros(normalized_shape), requires_grad=True)
        self.eps = eps
        self.data_format = data_format
        if self.data_format not in ["channels_last", "channels_first"]:
            raise ValueError(f"not support data format '{self.data_format}'")
        self.normalized_shape = (normalized_shape,)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        if self.data_format == "channels_last":
            return F.layer_norm(x, self.normalized_shape, self.weight, self.bias, self.eps)
        elif self.data_format == "channels_first":
            # [batch_size, channels, height, width]
            mean = x.mean(1, keepdim=True)
            var = (x - mean).pow(2).mean(1, keepdim=True)
            x = (x - mean) / torch.sqrt(var + self.eps)
            x = self.weight[:, None, None] * x + self.bias[:, None, None]
            return x

# %%
class GRN(nn.Module):
    """ GRN (Global Response Normalization) layer
    """
    def __init__(self, dim):
        super().__init__()
        self.gamma = nn.Parameter(torch.zeros(1, 1, 1, dim))
        self.beta = nn.Parameter(torch.zeros(1, 1, 1, dim))

    def forward(self, x):
        Gx = torch.norm(x, p=2, dim=(1,2), keepdim=True)
        Nx = Gx / (Gx.mean(dim=-1, keepdim=True) + 1e-6)
        return self.gamma * (x * Nx) + self.beta + x

# %%
class MinkowskiGRN(nn.Module):
    """ GRN layer for sparse tensors.
    """
    def __init__(self, dim):
        super().__init__()
        self.gamma = nn.Parameter(torch.zeros(1, dim))
        self.beta = nn.Parameter(torch.zeros(1, dim))

    def forward(self, x):
        cm = x.coordinate_manager
        in_key = x.coordinate_map_key

        Gx = torch.norm(x.F, p=2, dim=0, keepdim=True)
        Nx = Gx / (Gx.mean(dim=-1, keepdim=True) + 1e-6)
        return SparseTensor(
                self.gamma * (x.F * Nx) + self.beta + x.F,
                coordinate_map_key=in_key,
                coordinate_manager=cm)

# %%
class MinkowskiDropPath(nn.Module):
    """ Drop Path for sparse tensors.
    """

    def __init__(self, drop_prob: float = 0., scale_by_keep: bool = True):
        super(MinkowskiDropPath, self).__init__()
        self.drop_prob = drop_prob
        self.scale_by_keep = scale_by_keep

    def forward(self, x):
        if self.drop_prob == 0. or not self.training:
            return x
        cm = x.coordinate_manager
        in_key = x.coordinate_map_key
        keep_prob = 1 - self.drop_prob
        mask = torch.cat([
            torch.ones(len(_)) if random.uniform(0, 1) > self.drop_prob
            else torch.zeros(len(_)) for _ in x.decomposed_coordinates
        ]).view(-1, 1).to(x.device)
        if keep_prob > 0.0 and self.scale_by_keep:
            mask.div_(keep_prob)
        return SparseTensor(
                x.F * mask,
                coordinate_map_key=in_key,
                coordinate_manager=cm)

# %%
class MinkowskiLayerNorm(nn.Module):
    """ Channel-wise layer normalization for sparse tensors.
    """

    def __init__(
        self,
        normalized_shape,
        eps=1e-6,
    ):
        super(MinkowskiLayerNorm, self).__init__()
        self.ln = nn.LayerNorm(normalized_shape, eps=eps)
    def forward(self, input):
        output = self.ln(input.F)
        return SparseTensor(
            output,
            coordinate_map_key=input.coordinate_map_key,
            coordinate_manager=input.coordinate_manager)

# %%
class SparseBlock(nn.Module):
    """ Sparse ConvNeXtV2 Block.

    Args:
        dim (int): Number of input channels.
        drop_path (float): Stochastic depth rate. Default: 0.0
        layer_scale_init_value (float): Init value for Layer Scale. Default: 1e-6.
    """
    def __init__(self, dim, drop_path=0., D=3):
        super().__init__()
        self.dwconv = MinkowskiChannelwiseConvolution(dim, kernel_size=7, bias=True, dimension=D)
        self.norm = MinkowskiLayerNorm(dim, 1e-6)
        self.pwconv1 = MinkowskiLinear(dim, 4 * dim)
        self.act = MinkowskiGELU()
        self.pwconv2 = MinkowskiLinear(4 * dim, dim)
        self.grn = MinkowskiGRN(4  * dim)
        self.drop_path = MinkowskiDropPath(drop_path)

    def forward(self, x):
        input = x
        x = self.dwconv(x)
        x = self.norm(x)
        x = self.pwconv1(x)
        x = self.act(x)
        x = self.grn(x)
        x = self.pwconv2(x)
        x = input + self.drop_path(x)
        return x

# %%
class SparseConvNeXtV2(nn.Module):
    """ Sparse ConvNeXtV2.

    Args:
        in_chans (int): Number of input image channels. Default: 3
        num_classes (int): Number of classes for classification head. Default: 1000
        depths (tuple(int)): Number of blocks at each stage. Default: [3, 3, 9, 3]
        dims (int): Feature dimension at each stage. Default: [96, 192, 384, 768]
        drop_path_rate (float): Stochastic depth rate. Default: 0.
        head_init_scale (float): Init scaling value for classifier weights and biases. Default: 1.
    """
    def __init__(self,
                 in_chans=3,
                 num_classes=1000,
                 depths=[3, 3, 9, 3],
                 dims=[96, 192, 384, 768],
                 drop_path_rate=0.,
                 D=3):
        super().__init__()
        self.depths = depths
        self.num_classes = num_classes
        self.downsample_layers = nn.ModuleList() # stem and 3 intermediate downsampling conv layers
        stem = nn.Sequential(
            nn.Conv2d(in_chans, dims[0], kernel_size=4, stride=4),
            LayerNorm(dims[0], eps=1e-6, data_format="channels_first")
        )
        self.downsample_layers.append(stem)
        for i in range(3):
            downsample_layer = nn.Sequential(
                MinkowskiLayerNorm(dims[i], eps=1e-6),
                MinkowskiConvolution(dims[i], dims[i+1], kernel_size=2, stride=2, bias=True, dimension=D)
            )
            self.downsample_layers.append(downsample_layer)

        self.stages = nn.ModuleList() # 4 feature resolution stages, each consisting of multiple residual blocks
        dp_rates=[x.item() for x in torch.linspace(0, drop_path_rate, sum(depths))]
        cur = 0
        for i in range(4):
            stage = nn.Sequential(
                *[SparseBlock(dim=dims[i], drop_path=dp_rates[cur + j], D=D) for j in range(depths[i])]
            )
            self.stages.append(stage)
            cur += depths[i]

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, MinkowskiConvolution):
            trunc_normal_(m.kernel, std=.02)
            nn.init.constant_(m.bias, 0)
        if isinstance(m, MinkowskiChannelwiseConvolution):
            trunc_normal_(m.kernel, std=.02)
            nn.init.constant_(m.bias, 0)
        if isinstance(m, MinkowskiLinear):
            trunc_normal_(m.linear.weight, std=.02)
            nn.init.constant_(m.linear.bias, 0)

    def upsample_mask(self, mask, scale):
        assert len(mask.shape) == 2
        p = int(mask.shape[1] ** .5)
        return mask.reshape(-1, p, p).\
                    repeat_interleave(scale, axis=1).\
                    repeat_interleave(scale, axis=2)

    def forward(self, x, mask):
        num_stages = len(self.stages)
        mask = self.upsample_mask(mask, 2**(num_stages-1))
        mask = mask.unsqueeze(1).type_as(x)

        # patch embedding
        x = self.downsample_layers[0](x)
        x *= (1.-mask)

        # sparse encoding
        x = to_sparse(x)
        for i in range(4):
            x = self.downsample_layers[i](x) if i > 0 else x
            x = self.stages[i](x)

        # densify
        x = x.dense()[0]
        return x

# %%
def drop_path(x, drop_prob: float = 0., training: bool = False):
    if drop_prob == 0. or not training:
        return x
    keep_prob = 1 - drop_prob
    shape = (x.shape[0],) + (1,) * (x.ndim - 1)
    random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
    random_tensor.floor_()  # binarize
    output = x.div(keep_prob) * random_tensor
    return output

# %% [markdown]
# ## Decoder

# %%
class DropPathDecoder(nn.Module):
    """
        Drop paths (Stochastic Depth) per sample  (when applied in main path of residual blocks).

    """
    def __init__(self, drop_prob=None):
        super(DropPathConvnextV2, self).__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        return drop_path(x, self.drop_prob, self.training)

# %%
class BlockDecoder(nn.Module):
    """
        ConvNeXtV2 Block.

        Args:
            dim (int): Number of input channels.
            drop_path (float): Stochastic depth rate. Default: 0.0

    """
    def __init__(self, dim, drop_path=0.):
        super().__init__()
        self.dwconv = nn.Conv2d(dim, dim, kernel_size=7, padding=3, groups=dim) # depthwise conv
        self.norm = LayerNorm(dim, eps=1e-6)
        self.pwconv1 = nn.Linear(dim, 4 * dim) # pointwise/1x1 convs, implemented with linear layers
        self.act = nn.GELU()
        self.grn = GRN(4 * dim)
        self.pwconv2 = nn.Linear(4 * dim, dim)
        self.drop_path = DropPathDecoder(drop_path) if drop_path > 0. else nn.Identity()

    def forward(self, x):
        input = x
        x = self.dwconv(x)
        x = x.permute(0, 2, 3, 1) # (N, C, H, W) -> (N, H, W, C)
        x = self.norm(x)
        x = self.pwconv1(x)
        x = self.act(x)
        x = self.grn(x)
        x = self.pwconv2(x)
        x = x.permute(0, 3, 1, 2) # (N, H, W, C) -> (N, C, H, W)

        x = input + self.drop_path(x)
        return x

# %% [markdown]
# ## FCMAE

# %%
class FCMAE(nn.Module):
    """
        Fully Convolutional Masked Autoencoder with ConvNeXtV2 backbone

    """
    def __init__(
                self,
                img_size=224,
                in_chans=3,
                depths=[3, 3, 9, 3],
                dims=[96, 192, 384, 768],
                decoder_depth=1,
                decoder_embed_dim=512,
                patch_size=32,
                mask_ratio=0.6,
                norm_pix_loss=False):
        super().__init__()

        # configs
        self.img_size = img_size
        self.depths = depths
        self.imds = dims
        self.patch_size = patch_size
        self.mask_ratio = mask_ratio
        self.num_patches = (img_size // patch_size) ** 2
        self.decoder_embed_dim = decoder_embed_dim
        self.decoder_depth = decoder_depth
        self.norm_pix_loss = norm_pix_loss

        # encoder
        self.encoder = SparseConvNeXtV2(
            in_chans=in_chans, depths=depths, dims=dims, D=2)
        # decoder
        self.proj = nn.Conv2d(
            in_channels=dims[-1],
            out_channels=decoder_embed_dim,
            kernel_size=1)
        # mask tokens
        self.mask_token = nn.Parameter(torch.zeros(1, decoder_embed_dim, 1, 1))
        decoder = [BlockDecoder(
            dim=decoder_embed_dim,
            drop_path=0.) for i in range(decoder_depth)]
        self.decoder = nn.Sequential(*decoder)
        # pred
        self.pred = nn.Conv2d(
            in_channels=decoder_embed_dim,
            out_channels=patch_size ** 2 * in_chans,
            kernel_size=1)





    def patchify(self, imgs):
        """
        imgs: (N, 3, H, W)
        x: (N, L, patch_size**2 *3)
        """
        p = self.patch_size
        assert imgs.shape[2] == imgs.shape[3] and imgs.shape[2] % p == 0

        h = w = imgs.shape[2] // p
        x = imgs.reshape(shape=(imgs.shape[0], 3, h, p, w, p))
        x = torch.einsum('nchpwq->nhwpqc', x)
        x = x.reshape(shape=(imgs.shape[0], h * w, p**2 * 3))
        return x

    def unpatchify(self, x):
        """
        x: (N, L, patch_size**2 *3)
        imgs: (N, 3, H, W)
        """
        p = self.patch_size
        h = w = int(x.shape[1]**.5)
        assert h * w == x.shape[1]

        x = x.reshape(shape=(x.shape[0], h, w, p, p, 3))
        x = torch.einsum('nhwpqc->nchpwq', x)
        imgs = x.reshape(shape=(x.shape[0], 3, h * p, h * p))
        return imgs

    def gen_random_mask(self, x, mask_ratio):
        N = x.shape[0]
        L = (x.shape[2] // self.patch_size) ** 2
        len_keep = int(L * (1 - mask_ratio))

        noise = torch.randn(N, L, device=x.device)

        # sort noise for each sample
        ids_shuffle = torch.argsort(noise, dim=1)
        ids_restore = torch.argsort(ids_shuffle, dim=1)

        # generate the binary mask: 0 is keep 1 is remove
        mask = torch.ones([N, L], device=x.device)
        mask[:, :len_keep] = 0
        # unshuffle to get the binary mask
        mask = torch.gather(mask, dim=1, index=ids_restore)
        return mask

    def upsample_mask(self, mask, scale):
        assert len(mask.shape) == 2
        p = int(mask.shape[1] ** .5)
        return mask.reshape(-1, p, p).\
                    repeat_interleave(scale, axis=1).\
                    repeat_interleave(scale, axis=2)

    def forward_encoder(self, imgs, mask_ratio):
        # generate random masks
        mask = self.gen_random_mask(imgs, mask_ratio)
        # encoding
        x = self.encoder(imgs, mask)
        return x, mask

    def forward_decoder(self, x, mask):
        x = self.proj(x)
        # append mask token
        n, c, h, w = x.shape
        mask = mask.reshape(-1, h, w).unsqueeze(1).type_as(x)
        mask_token = self.mask_token.repeat(x.shape[0], 1, x.shape[2], x.shape[3])
        x = x * (1. - mask) + mask_token * mask
        # decoding
        x = self.decoder(x)
        # pred
        pred = self.pred(x)
        return pred

    def forward_loss(self, imgs, pred, mask):
        """
        imgs: [N, 3, H, W]
        pred: [N, L, p*p*3]
        mask: [N, L], 0 is keep, 1 is remove
        """
        if len(pred.shape) == 4:
            n, c, _, _ = pred.shape
            pred = pred.reshape(n, c, -1)
            pred = torch.einsum('ncl->nlc', pred)

        target = self.patchify(imgs)
        if self.norm_pix_loss:
            mean = target.mean(dim=-1, keepdim=True)
            var = target.var(dim=-1, keepdim=True)
            target = (target - mean) / (var + 1.e-6)**.5
        loss = (pred - target) ** 2
        loss = loss.mean(dim=-1)  # [N, L], mean loss per patch

        loss = (loss * mask).sum() / mask.sum()  # mean loss on removed patches
        return loss

    def forward(self, imgs, labels=None, mask_ratio=0.6):
        x, mask = self.forward_encoder(imgs, mask_ratio)
        pred = self.forward_decoder(x, mask)
        loss = self.forward_loss(imgs, pred, mask)
        return loss, pred, mask

# %%
def convnextv2_tiny(**kwargs):
    model = FCMAE(
        depths=[3, 3, 9, 3], dims=[96, 192, 384, 768], **kwargs)
    return model

# %% [markdown]
# # Train

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, lr_scheduler):
    model.train()

    accu_loss = torch.zeros(1).to(device)
    optimizer.zero_grad()

    data_loader = tqdm(data_loader, file=sys.stdout)
    for step, images in enumerate(data_loader):
        loss, pred, mask = model(images.to(device))

        loss.backward()
        accu_loss += loss.detach()

        data_loader.desc = "[train epoch {}] loss: {:.3f}, lr: {:.8f}".format(
            epoch,
            accu_loss.item() / (step + 1),
            optimizer.param_groups[0]["lr"],
        )

        if not torch.isfinite(loss):
            print('WARNING: non-finite loss, ending training ', loss)
            sys.exit(1)

        optimizer.step()
        optimizer.zero_grad()
        # update lr
        lr_scheduler.step()

    return accu_loss.item() / (step + 1)

# %%
@torch.no_grad()
def evaluate(model, data_loader, device, epoch):
    model.eval()
    accu_loss = torch.zeros(1).to(device)

    data_loader = tqdm(data_loader, file=sys.stdout)
    for step, images in enumerate(data_loader):
        loss, pred, mask = model(images.to(device))

        accu_loss += loss.detach()

        data_loader.desc = "[valid epoch {}] loss: {:.3f}".format(
            epoch,
            accu_loss.item() / (step + 1),
        )

    return accu_loss.item() / (step + 1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"using {device} device.")
# Out:
# using cuda device.

# %%
if os.path.exists("./weights") is False:
    os.makedirs("./weights")

# %%
img_size = 224
train_transform = transforms.Compose([transforms.Resize((img_size,img_size)),
                                    transforms.CenterCrop(img_size),
                                    transforms.RandomHorizontalFlip(p=0.5),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

train_dataset = MyDataset(train_images_path, train_transform)

# %%
batch_size = 32
torch.manual_seed(42)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

# %%
model = convnextv2_tiny().to(device)

# %%
# !pip install torchinfo

# %%
from torchinfo import summary
summary(model)

# %%
def create_lr_scheduler(optimizer,
                        num_step: int,
                        epochs: int,
                        warmup=True,
                        warmup_epochs=1,
                        warmup_factor=1e-3,
                        end_factor=1e-6):
    assert num_step > 0 and epochs > 0
    if warmup is False:
        warmup_epochs = 0

    def f(x):
        if warmup is True and x <= (warmup_epochs * num_step):
            alpha = float(x) / (warmup_epochs * num_step)
            return warmup_factor * (1 - alpha) + alpha
        else:
            current_step = (x - warmup_epochs * num_step)
            cosine_steps = (epochs - warmup_epochs) * num_step
            return ((1 + math.cos(current_step * math.pi / cosine_steps)) / 2) * (1 - end_factor) + end_factor

    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=f)

# %%
epochs = 50
lr = 3e-3
optimizer = torch.optim.Adam(params=model.parameters(),
                            lr=1e-3,
                            weight_decay=1e-5)
lr_scheduler = create_lr_scheduler(optimizer, len(train_loader), epochs,
                                   warmup=True, warmup_epochs=1)

# %%
best_loss = 1e9
patience = 0
for epoch in range(epochs):
    if epoch >= 25:
      break
    train_loss = train_one_epoch(model=model,
                                optimizer=optimizer,
                                data_loader=train_loader,
                                device=device,
                                epoch=epoch,
                                lr_scheduler=lr_scheduler)
    torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': lr_scheduler.state_dict(),
            }, "best_model.pth")

# %%
def denormalize(img_bchw,image_mean,image_std):
    """
    Denormalize the image for correct visualization.
    """
    return img_bchw.mul(image_std).add_(image_mean).clamp_(0., 1.)

# %% [markdown]
# # Visualize result image

# %%
import matplotlib.pyplot as plt

# %%
def show_one_image(model, image, image_mean,image_std,output_path):
    try:
        model.eval()
        with torch.no_grad():
            for image in image:
                image = image.to(device)
                loss, predictions, mask = model(image)
    except RuntimeError:
        return
    patch_size = 32
    mask = mask.unsqueeze(-1).repeat(1, 1, (patch_size**2 * 3))

    predictions = predictions.view(1, patch_size**2 * 3, -1).permute(0, 2, 1)
    predictions = model.unpatchify(predictions )

    mask = model.unpatchify(mask).to(device)

    im_masked = image * (1 - mask)
    rec_and_img = predictions * mask + im_masked
    channel_means = image.mean(dim=[2, 3], keepdim=True)
    im_mean_in = image * (1 - mask) + mask * channel_means

    # Denormalizing the images before visualization
    pred_img = denormalize(predictions * mask,image_mean=image_mean,image_std=image_std)[0].permute(1, 2, 0).cpu().detach().numpy()
    masked_img = denormalize(im_masked,image_mean=image_mean,image_std=image_std)[0].permute(1, 2, 0).cpu().detach().numpy()
    rec_img = denormalize(rec_and_img,image_mean=image_mean,image_std=image_std)[0].permute(1, 2, 0).cpu().detach().numpy()
    im_mean_in = denormalize(im_mean_in,image_mean=image_mean,image_std=image_std)[0].permute(1, 2, 0).cpu().detach().numpy()
    orig_img = denormalize(image,image_mean=image_mean,image_std=image_std)[0].permute(1, 2, 0).cpu().numpy()

    # Plot the original, masked, and reconstructed images
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 4, 1)
    plt.title("Original Image",fontsize=8)
    plt.imshow(orig_img)
    plt.axis('off')

    plt.subplot(1, 4, 2)
    plt.title("Masked Image",fontsize=8)
    plt.imshow(masked_img)
    plt.axis('off')

    plt.subplot(1, 4, 3)
    plt.title("Reconstructed Image",fontsize=8)
    plt.imshow(pred_img)
    plt.axis('off')

    plt.subplot(1, 4, 4)
    plt.title("Reconstructed + Masked Image",fontsize=8)
    plt.imshow(rec_img)
    plt.axis('off')

    plt.savefig(output_path)
    plt.show()

# %%
dataiter = train_images_path[:1]
dataiter

# %%
dataiter = MyDataset(dataiter, train_transform)
dataex = torch.utils.data.DataLoader(dataiter,
                                   batch_size=batch_size,
                                   shuffle=True,
                                   pin_memory=True,
                                   num_workers=nw,)

# %%
for batch in dataex:
    print(batch.shape)

# %%
IMAGENET_RGB_MEAN = torch.tensor((0.485, 0.456, 0.406), device=device).reshape(1, 3, 1, 1)
IMAGENET_RGB_STD = torch.tensor((0.229, 0.224, 0.225), device=device).reshape(1, 3, 1, 1)
show_one_image(model=model,
               image=dataex,
               image_mean=IMAGENET_RGB_MEAN,
               image_std=IMAGENET_RGB_STD,
               output_path= 'visualize.png'
                        )
